# %%
import os
import pandas as pd
from PIL import Image
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score
import torch.nn.functional as F

# %% [markdown]
# ## Task 2. Functions, Focal Loss, and Class-Balanced Loss
#
# This section contains the core utility functions and custom loss modules used in training.
# They provide consistent handling of class imbalance and can be reused across all backbones and experimental setups.
#
# - **Focal Loss** focuses learning on hard examples by down-weighting easy predictions.
# - **Class-Balanced BCE Loss** adjusts each class’s contribution based on inverse frequency computed from the training data.
#
# These components help stabilize multi-label training when classes appear with different frequencies.

# %%
# ========================
# Dataset preparation
# ========================
class RetinaMultiLabelDataset(Dataset):
    def __init__(self, csv_file, image_dir, transform=None):
        self.data = pd.read_csv(csv_file)
        self.image_dir = image_dir
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        img_path = os.path.join(self.image_dir, row.iloc[0])
        img = Image.open(img_path).convert("RGB")
        labels = torch.tensor(row[1:].values.astype("float32"))
        if self.transform:
            img = self.transform(img)
        return img, labels

class RetinaTestDataset(Dataset):
    def __init__(self, csv_file, image_dir, transform=None):
        df = pd.read_csv(csv_file)
        self.ids = df.iloc[:, 0].values  # first column -> id/ID
        self.image_dir = image_dir
        self.transform = transform

    def __len__(self):
        return len(self.ids)

    def __getitem__(self, idx):
        img_id = self.ids[idx]
        img_path = os.path.join(self.image_dir, img_id)
        img = Image.open(img_path).convert("RGB")
        if self.transform:
            img = self.transform(img)
        return img, img_id

# %%
# ========================
# build model
# ========================
from torchvision.models import resnet18, ResNet18_Weights
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights

def build_model(backbone="resnet18", num_classes=3, pretrained=True):
    if backbone == "resnet18":
        weights = ResNet18_Weights.IMAGENET1K_V1 if pretrained else None
        model = resnet18(weights=weights)
        model.fc = nn.Linear(model.fc.in_features, num_classes)

    elif backbone == "efficientnet":
        weights = EfficientNet_B0_Weights.IMAGENET1K_V1 if pretrained else None
        model = efficientnet_b0(weights=weights)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)

    else:
        raise ValueError("Unsupported backbone")

    return model

# %%
# FocalLoss
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2.0, reduction="mean"):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.reduction = reduction

        if alpha is not None:
            alpha = torch.tensor(alpha, dtype=torch.float32)
        self.alpha = alpha

    def forward(self, logits, targets):
        """
        logits: [B, C] raw model outputs
        targets: [B, C] in {0,1}
        """
        bce_loss = F.binary_cross_entropy_with_logits(
            logits, targets, reduction="none"
        )
        probs = torch.sigmoid(logits)
        p_t = probs * targets + (1 - probs) * (1 - targets)

        if self.alpha is not None:
            alpha = self.alpha.to(logits.device)
            # broadcast alpha if it's per-class
            if alpha.dim() == 1:
                alpha = alpha.view(1, -1)  # [1, C]
            alpha_t = alpha * targets + (1 - alpha) * (1 - targets)
        else:
            alpha_t = 1.0

        # focal modulation
        focal_factor = (1.0 - p_t) ** self.gamma
        loss = alpha_t * focal_factor * bce_loss  # [B, C]

        if self.reduction == "mean":
            return loss.mean()
        elif self.reduction == "sum":
            return loss.sum()
        else:
            return loss  # [B, C]

# %%
# ClassBalancedBCELoss
def compute_class_frequency_weights_from_csv(train_csv_path, num_classes=3):
    df = pd.read_csv(train_csv_path)
    label_cols = df.columns[1 : 1 + num_classes]  # skip ID
    pos_counts = df[label_cols].sum(axis=0).values.astype(np.float32)
    total = len(df)

    # positive frequency per class
    freq = pos_counts / (total + 1e-6)

    # inverse frequency as weights
    inv_freq = 1.0 / (freq + 1e-6)
    inv_freq = inv_freq / inv_freq.mean()

    return torch.tensor(inv_freq, dtype=torch.float32)
class ClassBalancedBCELoss(nn.Module):
    def __init__(self, class_weights, reduction="mean"):
        super(ClassBalancedBCELoss, self).__init__()
        self.class_weights = class_weights  
        self.reduction = reduction

    def forward(self, logits, targets):
        """
        logits: [B, C]
        targets: [B, C]
        """
        bce = F.binary_cross_entropy_with_logits(
            logits, targets, reduction="none"
        )

        w = self.class_weights.to(logits.device).view(1, -1)
        loss = bce * w

        if self.reduction == "mean":
            return loss.mean()
        elif self.reduction == "sum":
            return loss.sum()
        else:
            return loss

# %%
# ========================
# model training and val
# ========================
def train_one_backbone(
    backbone,
    train_csv,
    val_csv,
    test_csv,
    train_image_dir,
    val_image_dir,
    test_image_dir,
    epochs=10,
    batch_size=32,
    lr=1e-4,
    img_size=256,
    save_dir="checkpoints",
    pretrained_backbone=None,
    task="full_ft",
    loss="bce",  # "bce", "focal", "cb"
    alpha = None,
    gamma = 2.0,
):

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(device)

    task_name_map = {
        "no_finetune": "Task1.1 No fine-tuning",
        "cls_only": "Task1.2 Frozen backbone, classifier only",
        "full_ft": "Task1.3 Full fine-tuning",
    }

    print("===========================================")
    print(f"Task 2 |  Backbone: {backbone} | loss: {loss}")
    print("===========================================")

    # transforms
    transform = transforms.Compose(
        [
            transforms.Resize((img_size, img_size)),
            transforms.ToTensor(),
            transforms.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
        ]
    )

    # datasets & dataloaders
    train_ds = RetinaMultiLabelDataset(train_csv, train_image_dir, transform)
    val_ds = RetinaMultiLabelDataset(val_csv, val_image_dir,transform)
    test_ds = RetinaMultiLabelDataset(test_csv, test_image_dir, transform)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=0)
    val_loader   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False, num_workers=0)
    test_loader  = DataLoader(test_ds,  batch_size=batch_size, shuffle=False, num_workers=0)


    # model
    model = build_model(backbone, num_classes=3, pretrained=False).to(device)

    if pretrained_backbone is not None:
        state_dict = torch.load(pretrained_backbone, map_location="cpu")
        model.load_state_dict(state_dict)
        print(f"Loaded pretrained weights from {pretrained_backbone}")

    # set which parameters are trainable
    if task == "no_finetune":
        # everything is frozen
        for p in model.parameters():
            p.requires_grad = False
        optimizer = None
    elif task == "cls_only":
        # freeze backbone
        for p in model.parameters():
            p.requires_grad = False
        # unfreeze classifier
        if backbone == "resnet18":
            for p in model.fc.parameters():
                p.requires_grad = True
        elif backbone == "efficientnet":
            for p in model.classifier.parameters():
                p.requires_grad = True
        optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=lr)
    else:  # full_ft
        for p in model.parameters():
            p.requires_grad = True
        optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=lr)
        #scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3,)


    # ----- choose loss function -----
    if loss == "bce":
        # plain BCE
        criterion = nn.BCEWithLogitsLoss()

    elif loss == "focal":
        # Task 2.1: Focal Loss
        criterion = FocalLoss(alpha=alpha, gamma=gamma, reduction="mean")

    elif loss == "cb":
        # Task 2.2: Class-Balanced BCE Loss
        class_weights = compute_class_frequency_weights_from_csv(train_csv, num_classes=3)
        criterion = ClassBalancedBCELoss(class_weights=class_weights, reduction="mean")

    else:
        raise ValueError(f"Unknown loss_type: {loss_type}")


    # checkpoint path (unique per backbone + task)
    os.makedirs(save_dir, exist_ok=True)
    task_file_map = {
    "bce": "task1",
    "focal":    "task2_1",
    "cb":     "task2_2",
    }
    task_prefix = task_file_map[loss] 
    ckpt_path = os.path.join(save_dir, f"csu_{task_prefix}_{backbone}.pt")

    # ========= TRAINING (only for Task1.2 and Task1.3) =========
    if task != "no_finetune":
        best_val_loss = float("inf")

        for epoch in range(epochs):
            model.train()
            train_loss = 0.0
            for imgs, labels in train_loader:
                imgs, labels = imgs.to(device), labels.to(device)
                optimizer.zero_grad()
                outputs = model(imgs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                train_loss += loss.item() * imgs.size(0)

            train_loss /= len(train_loader.dataset)

            # validation
            model.eval()
            val_loss = 0.0
            val_probs_all = []
            val_labels_all = []

            with torch.no_grad():
                for imgs, labels in val_loader:
                    imgs, labels = imgs.to(device), labels.to(device)
                    outputs = model(imgs)
                    loss = criterion(outputs, labels)
                    val_loss += loss.item() * imgs.size(0)
                    probs = torch.sigmoid(outputs).cpu().numpy()
                    val_probs_all.extend(probs)
                    val_labels_all.extend(labels.cpu().numpy())
            val_loss /= len(val_loader.dataset)
            val_probs_all = np.array(val_probs_all)
            val_labels_all = np.array(val_labels_all)

            #scheduler.step(val_loss)

            print(f"[{backbone}] Epoch {epoch+1}/{epochs} Train Loss: {train_loss:.4f} Val Loss: {val_loss:.4f}")

            # save best
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                torch.save(model.state_dict(), ckpt_path)
                print(f"Saved best model for {backbone} ({task}) at {ckpt_path}")
    else:
        torch.save(model.state_dict(), ckpt_path)
        print(f"[{backbone}] {task_name_map[loss]}: no training, model saved at {ckpt_path}")

    # ========= OFFSITE TEST EVALUATION =========
    model.load_state_dict(torch.load(ckpt_path, map_location=device))
    model.to(device)
    model.eval()

    y_true, y_pred = [], []

    with torch.no_grad():
        for imgs, labels in test_loader:
            imgs = imgs.to(device)
            outputs = model(imgs)
            probs = torch.sigmoid(outputs).cpu().numpy()
            preds = (probs > 0.5).astype(int)
            y_true.extend(labels.numpy())
            y_pred.extend(preds)

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    return ckpt_path, y_true, y_pred, val_probs_all, val_labels_all

# %%
def generate_kaggle_submission(
    backbone,
    ckpt_path,
    onsite_csv,
    onsite_image_dir,
    img_size=256,
    batch_size=32,
    out_csv="submission.csv",
    threshold=0.5,
    best = False,
):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    transform = transforms.Compose(
        [
            transforms.Resize((img_size, img_size)),
            transforms.ToTensor(),
            transforms.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
        ]
    )

    # build model and load weights
    model = build_model(backbone, num_classes=3, pretrained=False).to(device)
    model.load_state_dict(torch.load(ckpt_path, map_location=device))
    model.eval()

    # read the original Kaggle template
    template = pd.read_csv(onsite_csv)
    id_col_name = template.columns[0]  # should be 'id'

    # dataset and loader use the same csv for IDs
    test_ds = RetinaTestDataset(onsite_csv, onsite_image_dir, transform)
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=0)

    ids = []
    probs_all = []

    with torch.no_grad():
        for imgs, img_ids in test_loader:
            imgs = imgs.to(device)
            outputs = model(imgs)
            probs = torch.sigmoid(outputs).cpu().numpy() 
            ids.extend(img_ids)
            probs_all.append(probs)

    probs_all = np.concatenate(probs_all, axis=0)

    template_ids = template[id_col_name].values
    ids = np.array(ids)

    if not np.array_equal(template_ids, ids):
        print("WARNING: IDs in template and predictions do not match exactly in order!")
        id_to_idx = {image_id: i for i, image_id in enumerate(ids)}
        reorder_idx = [id_to_idx[x] for x in template_ids]
        probs_all = probs_all[reorder_idx, :]

    # convert probabilities to 0/1 labels using threshold
    if best ==True:
        
        thr = np.array(threshold, dtype=float)
    
        if thr.ndim == 0:  # scalar threshold
            bin_preds = (probs_all >= thr).astype(int)
        else:              # per-class thresholds
            bin_preds = (probs_all >= thr.reshape(1, -1)).astype(int)
    else:
        bin_preds = (probs_all >= threshold).astype(int)

    # overwrite D/G/A in template; keeps int dtypes and exact structure
    template["D"] = bin_preds[:, 0]
    template["G"] = bin_preds[:, 1]
    template["A"] = bin_preds[:, 2]

    # ensure output directory exists
    out_dir = "submission"
    os.makedirs(out_dir, exist_ok=True)
    out_path = os.path.join(out_dir, out_csv)
    tmp_path = out_path + ".tmp"
    template.to_csv(tmp_path, index=False)
    os.replace(tmp_path, out_path)

    print(f"Kaggle submission saved to: {out_path}")

# %%
def evaluating_metrics(y_true, y_pred, backbone, task_name,split_name):
    
    disease_names = ["DR", "Glaucoma", "AMD"]
    rows = []
    f1_list = []

    print(f"\n{split_name.upper()} test results for {backbone} - {task_name}")

    for i, disease in enumerate(disease_names):
        yt = y_true[:, i]
        yp = y_pred[:, i]

        acc = accuracy_score(yt, yp)
        precision = precision_score(yt, yp, zero_division=0)
        recall = recall_score(yt, yp, zero_division=0)
        f1 = f1_score(yt, yp, zero_division=0)
        kappa = cohen_kappa_score(yt, yp)

        f1_list.append(f1)

        """# print in the required format (optional)
        print(f"{disease} Results [{backbone}] ({split_name})")
        print(f"Accuracy : {acc:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall   : {recall:.4f}")
        print(f"F1-score : {f1:.4f}")
        print(f"Kappa    : {kappa:.4f}")
        print("-----")"""

        rows.append({
            "Backbone": backbone,
            "Task": task_name,
            "Split": split_name,
            "Disease": disease,
            "Accuracy": acc,
            "Precision": precision,
            "Recall": recall,
            "F1-score": f1,
            "Kappa": kappa,
        })

    avg_f1 = sum(f1_list) / len(f1_list)
    print(f"Average F1 over 3 diseases ({split_name}): {avg_f1:.4f}\n")

    rows.append({
        "Backbone": backbone,
        "Task": task_name,
        "Split": split_name,
        "Disease": "Average F1",
        "Accuracy": None,
        "Precision": None,
        "Recall": None,
        "F1-score": avg_f1,
        "Kappa": None,
    })

    return pd.DataFrame(rows)

# %% [markdown]
# ## Configuration
#
# This section defines all dataset paths, pretrained backbone locations, and key training hyperparameters. Adjust these values to match your local setup before running the experiments. The class frequency–based alpha vector is also computed here for optional use in loss functions. In the version I ran, this vector was not used, but you may enable it if you wish to experiment with it.

# %%
# Configuration (edit paths here)


# Labeled splits
train_csv = "train.csv"
val_csv = "val.csv"
offsite_test_csv = "offsite_test.csv"

train_img_dir = "./images/train"
val_img_dir = "./images/val"
offsite_img_dir = "./images/offsite_test"

# unlabeled onsite test (for kaggle submission)
onsite_csv = "onsite_test_submission.csv"
onsite_img_dir = "./images/onsite_test"

# optional: your own pretrained backbones
pretrained_resnet18 = "./pretrained_backbone/ckpt_resnet18_ep50.pt"
pretrained_efficient = "./pretrained_backbone/ckpt_efficientnet_ep50.pt"

img_size = 256
epochs = 20
batch_size = 32
lr = 1e-4
save_dir = "checkpoints"

# per-class alpha based on disease frequency
df = pd.read_csv(train_csv)
label_cols = df.columns[1:4]  
pos_counts = df[label_cols].sum(axis=0).values.astype(np.float32)
total = len(df)
freq = pos_counts / (total + 1e-6)
alpha_vec = 1.0 - freq
alpha_vec = alpha_vec / alpha_vec.max()

# %%
def find_best_thresholds(probs_val, y_val, disease_names=("DR","Glaucoma","AMD")):
    best_thrs = []
    for i, name in enumerate(disease_names):
        best_f1 = -1
        best_t = 0.5
        for t in np.linspace(0.1, 0.9, 81):
            preds = (probs_val[:, i] > t).astype(int)
            f1 = f1_score(y_val[:, i], preds, zero_division=0)
            if f1 > best_f1:
                best_f1, best_t = f1, t
        print(f"{name}: best thr={best_t:.2f}, val F1={best_f1:.4f}")
        best_thrs.append(best_t)
    return np.array(best_thrs)

# %% [markdown]
# ## Training
#
# This section includes all training runs used to generate the results presented in the report and submitted to Kaggle. The preliminary results and metrics shown here were used directly in the report, and the hyperparameters in the code match the exact configurations of the final experiments. Because training is stochastic, your results may not match mine exactly, but repeated runs should produce similar outcomes.
#
#
# Each task is organized into its own code block. For example:
#
# - `# Task 2.1  resnet18, focal loss`
#
# A separate section includes the large-scale hyperparameter search used to identify the best-performing settings. These experiments are commented out because they require substantial compute time, but the preliminary results are shown for reference.
#
# After running multiple trials, the best-performing configuration was selected for the final model and Kaggle submission. Your single run may not match the final score exactly, but repeated runs should produce similar performance. Though the number of repeated runs maybe large. And you need to have enough VRAM as some of the configurations were using batch_size = 128.

# %%
# Task 2.1  resnet18, focal Loss

backbone = "resnet18" 

if backbone == "resnet18":
    pretrained_path = pretrained_resnet18
elif backbone == "efficientnet":
    pretrained_path = pretrained_efficient
else:
    raise ValueError("unknown backbone")
    
checkpoint = "./checkpoints/task1/csu_task1_2_resnet18.pt"
#offsite
ckpt_task21, y_true_offsite, y_pred_offsite, val_probs, val_labels = train_one_backbone(
    backbone=backbone,
    train_csv=train_csv,
    val_csv=val_csv,
    test_csv=offsite_test_csv,
    train_image_dir=train_img_dir,
    val_image_dir=val_img_dir,
    test_image_dir=offsite_img_dir,
    epochs=12,
    batch_size=128,
    lr=5e-4,
    img_size=img_size,
    save_dir=save_dir,
    pretrained_backbone=checkpoint,
    task="full_ft",
    loss="focal", 
    alpha =None,
    gamma = 2,
)


best_thrs = find_best_thresholds(val_probs, val_labels)

#onsite
generate_kaggle_submission(
    backbone=backbone,
    ckpt_path=ckpt_task21,
    onsite_csv=onsite_csv,          
    onsite_image_dir=onsite_img_dir,
    img_size=img_size,
    batch_size=batch_size,
    out_csv=f"submission_{backbone}_task2_1.csv",
    threshold = 0.5,
    best = False,
)

df_offsite = evaluating_metrics(
    y_true=y_true_offsite,
    y_pred=y_pred_offsite,
    backbone=backbone,
    task_name="full_ft",
    split_name="offsite",
)


torch.cuda.empty_cache()
df_offsite
# Out:
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: focal
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.1121 Val Loss: 0.2575
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_1_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.0557 Val Loss: 0.3255
# [resnet18] Epoch 3/12 Train Loss: 0.0307 Val Loss: 0.2073
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_1_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.0177 Val Loss: 0.1813
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_1_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.0125 Val Loss: 0.2346
# [resnet18] Epoch 6/12 Train Loss: 0.0109 Val Loss: 0.2636
# [resnet18] Epoch 7/12 Train Loss: 0.0072 Val Loss: 0.2360
# [resnet18] Epoch 8/12 Train Loss: 0.0056 Val Loss: 0.2362
# [resnet18] Epoch 9/12 Train Loss: 0.0033 Val Loss: 0.2976
# [resnet18] Epoch 10/12 Train Loss: 0.0022 Val Loss: 0.3204
# [resnet18] Epoch 11/12 Train Loss: 0.0021 Val Loss: 0.3075
# [resnet18] Epoch 12/12 Train Loss: 0.0039 Val Loss: 0.3046
# DR: best thr=0.66, val F1=0.8167
# Glaucoma: best thr=0.15, val F1=0.8376
# AMD: best thr=0.51, val F1=0.7160
# Kaggle submission saved to: submission\submission_resnet18_task2_1.csv
#
# OFFSITE test results for resnet18 - full_ft
# Average F1 over 3 diseases (offsite): 0.7567
#    Backbone     Task    Split     Disease  Accuracy  Precision    Recall  \
# 0  resnet18  full_ft  offsite          DR     0.840   0.935484  0.828571
# 1  resnet18  full_ft  offsite    Glaucoma     0.905   0.800000  0.816327
# 2  resnet18  full_ft  offsite         AMD     0.900   0.538462  0.636364
# 3  resnet18  full_ft  offsite  Average F1       NaN        NaN       NaN
#
#    F1-score     Kappa
# 0  0.878788  0.646018
# 1  0.808081  0.744966
# 2  0.583333  0.526963
# 3  0.756734       NaN

# %%
# Task 2.1  efficientnet, focal Loss

backbone = "efficientnet" 

if backbone == "resnet18":
    pretrained_path = pretrained_resnet18
elif backbone == "efficientnet":
    pretrained_path = pretrained_efficient
else:
    raise ValueError("unknown backbone")
    
checkpoint = "./checkpoints/task1/csu_task1_2_efficientnet.pt"
#offsite
ckpt_task21, y_true_offsite, y_pred_offsite, val_probs, val_labels = train_one_backbone(
    backbone=backbone,
    train_csv=train_csv,
    val_csv=val_csv,
    test_csv=offsite_test_csv,
    train_image_dir=train_img_dir,
    val_image_dir=val_img_dir,
    test_image_dir=offsite_img_dir,
    epochs=10,
    batch_size=128,
    lr=1e-3,
    img_size=img_size,
    save_dir=save_dir,
    pretrained_backbone=checkpoint,
    task="full_ft",
    loss="focal", 
    alpha =None,
    gamma = 2,
)


best_thrs = find_best_thresholds(val_probs, val_labels)

#onsite
generate_kaggle_submission(
    backbone=backbone,
    ckpt_path=ckpt_task21,
    onsite_csv=onsite_csv,          
    onsite_image_dir=onsite_img_dir,
    img_size=img_size,
    batch_size=batch_size,
    out_csv=f"submission_{backbone}_task2_1.csv",
    threshold = 0.5,
    best = False,
)

df_offsite = evaluating_metrics(
    y_true=y_true_offsite,
    y_pred=y_pred_offsite,
    backbone=backbone,
    task_name="full_ft",
    split_name="offsite",
)


torch.cuda.empty_cache()
df_offsite
# Out:
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: focal
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/10 Train Loss: 0.1421 Val Loss: 0.2800
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_1_efficientnet.pt
# [efficientnet] Epoch 2/10 Train Loss: 0.0755 Val Loss: 0.2633
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_1_efficientnet.pt
# [efficientnet] Epoch 3/10 Train Loss: 0.0373 Val Loss: 0.2474
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_1_efficientnet.pt
# [efficientnet] Epoch 4/10 Train Loss: 0.0284 Val Loss: 0.2853
# [efficientnet] Epoch 5/10 Train Loss: 0.0198 Val Loss: 0.2969
# [efficientnet] Epoch 6/10 Train Loss: 0.0108 Val Loss: 0.2705
# [efficientnet] Epoch 7/10 Train Loss: 0.0070 Val Loss: 0.2642
# [efficientnet] Epoch 8/10 Train Loss: 0.0060 Val Loss: 0.2716
# [efficientnet] Epoch 9/10 Train Loss: 0.0032 Val Loss: 0.2793
# [efficientnet] Epoch 10/10 Train Loss: 0.0058 Val Loss: 0.2171
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_1_efficientnet.pt
# DR: best thr=0.52, val F1=0.8523
# Glaucoma: best thr=0.33, val F1=0.8108
# AMD: best thr=0.38, val F1=0.7317
# Kaggle submission saved to: submission\submission_efficientnet_task2_1.csv
#
# OFFSITE test results for efficientnet - full_ft
# Average F1 over 3 diseases (offsite): 0.7457
#        Backbone     Task    Split     Disease  Accuracy  Precision    Recall  \
# 0  efficientnet  full_ft  offsite          DR     0.825   0.877698  0.871429
# 1  efficientnet  full_ft  offsite    Glaucoma     0.885   0.809524  0.693878
# 2  efficientnet  full_ft  offsite         AMD     0.925   0.705882  0.545455
# 3  efficientnet  full_ft  offsite  Average F1       NaN        NaN       NaN
#
#    F1-score     Kappa
# 0  0.874552  0.585308
# 1  0.747253  0.673388
# 2  0.615385  0.574589
# 3  0.745730       NaN

# %%
# task 2.2 resnet18, try different hyperparameters to find the best ones
# No need to run this unless you are interested, though the pre result are preserved here just to show the exploration process.
"""import gc

backbone = "resnet18"
checkpoint = "./checkpoints/task1/csu_task1_2_resnet18.pt"  # starting checkpoint for full_ft

if backbone == "resnet18":
    pretrained_path = pretrained_resnet18
elif backbone == "efficientnet":
    pretrained_path = pretrained_efficient
else:
    raise ValueError("unknown backbone")

# -------------------------
# Hyperparameter grids
# -------------------------
lrs = [
    1e-3, 9e-4, 8e-4, 7e-4, 6e-4, 5e-4, 4e-4, 3e-4, 2e-4, 1e-4,
    9e-5, 8e-5, 7e-5, 6e-5, 5e-5, 4e-5, 3e-5, 2e-5, 1e-5
]
batch_sizes = [128, 64]

results = []  # will store dicts with ckpt_path, avg_f1, and hyperparams

exp_id = 0

for lr in lrs:
    for batch_size in batch_sizes:
        exp_id += 1
        print("=" * 60)
        print(f"Experiment {exp_id}: lr={lr}, batch_size={batch_size}")
        print("=" * 60)

        # ---- Train with given hyperparameters ----
        ckpt_path, y_true_offsite, y_pred_offsite, val_probs, val_labels = train_one_backbone(
            backbone=backbone,
            train_csv=train_csv,
            val_csv=val_csv,
            test_csv=offsite_test_csv,
            train_image_dir=train_img_dir,
            val_image_dir=val_img_dir,
            test_image_dir=offsite_img_dir,
            epochs=12,
            batch_size=batch_size,
            lr=lr,
            img_size=img_size,
            save_dir=save_dir,
            pretrained_backbone=checkpoint,  # or pretrained_path if you prefer
            task="full_ft",
            loss="cb",   # class-balanced loss, no alpha/gamma needed
        )

        # ---- Compute validation-based thresholds (for later use on onsite) ----
        best_thrs = find_best_thresholds(val_probs, val_labels)

        # ---- Compute OFFSITE metrics (used to rank models) ----
        df_off = evaluating_metrics(
            y_true=y_true_offsite,
            y_pred=y_pred_offsite,
            backbone=backbone,
            task_name=f"full_ft_cb_lr{lr}_bs{batch_size}",
            split_name="offsite",
        )

        # Extract average F1 row (assuming your df has 'Disease' == 'Average F1')
        try:
            avg_f1 = df_off.loc[df_off["Disease"] == "Average F1", "F1-score"].values[0]
        except Exception as e:
            print("WARNING: Could not extract average F1 from df_off, defaulting to 0.0")
            print("Error:", e)
            avg_f1 = 0.0

        print(f"OFFSITE Average F1 for this config: {avg_f1:.4f}")

        # ---- Store result ----
        results.append(
            {
                "ckpt_path": ckpt_path,
                "avg_f1": float(avg_f1),
                "lr": lr,
                "batch_size": batch_size,
                "best_thrs": best_thrs,
            }
        )

        # ---- Clean up GPU memory ----
        del y_true_offsite, y_pred_offsite, val_probs, val_labels
        gc.collect()
        torch.cuda.empty_cache()

# -------------------------
# Select top 3 configurations
# -------------------------
results_sorted = sorted(results, key=lambda x: x["avg_f1"], reverse=True)
top3 = results_sorted[:3]

print("\n" + "#" * 60)
print("TOP 3 CONFIGURATIONS (by OFFSITE average F1)")
print("#" * 60)

for rank, r in enumerate(top3, start=1):
    print(
        f"Rank {rank}: avg_F1={r['avg_f1']:.4f}, "
        f"lr={r['lr']}, batch_size={r['batch_size']}, "
        f"ckpt={r['ckpt_path']}"
    )

"""
# Out:
# ============================================================
# Experiment 1: lr=0.001, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4272 Val Loss: 1.1608
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2578 Val Loss: 1.7627
# [resnet18] Epoch 3/12 Train Loss: 0.1589 Val Loss: 0.6746
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.1003 Val Loss: 0.7972
# [resnet18] Epoch 5/12 Train Loss: 0.0754 Val Loss: 0.4941
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 6/12 Train Loss: 0.0601 Val Loss: 0.6466
# [resnet18] Epoch 7/12 Train Loss: 0.0481 Val Loss: 0.8278
# [resnet18] Epoch 8/12 Train Loss: 0.0384 Val Loss: 0.5468
# [resnet18] Epoch 9/12 Train Loss: 0.0292 Val Loss: 0.6384
# [resnet18] Epoch 10/12 Train Loss: 0.0553 Val Loss: 0.8260
# [resnet18] Epoch 11/12 Train Loss: 0.0620 Val Loss: 0.6511
# [resnet18] Epoch 12/12 Train Loss: 0.0427 Val Loss: 0.7179
# DR: best thr=0.29, val F1=0.7570
# Glaucoma: best thr=0.15, val F1=0.7358
# AMD: best thr=0.28, val F1=0.5432
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.001_bs128
# Average F1 over 3 diseases (offsite): 0.6391
#
# OFFSITE Average F1 for this config: 0.6391
# ============================================================
# Experiment 2: lr=0.001, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4459 Val Loss: 1.7538
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2930 Val Loss: 0.7672
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1763 Val Loss: 0.7546
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.1296 Val Loss: 0.4774
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.0880 Val Loss: 0.6990
# [resnet18] Epoch 6/12 Train Loss: 0.0666 Val Loss: 0.4744
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 7/12 Train Loss: 0.0448 Val Loss: 0.7281
# [resnet18] Epoch 8/12 Train Loss: 0.0314 Val Loss: 0.5767
# [resnet18] Epoch 9/12 Train Loss: 0.0321 Val Loss: 0.5643
# [resnet18] Epoch 10/12 Train Loss: 0.0357 Val Loss: 0.6867
# [resnet18] Epoch 11/12 Train Loss: 0.0402 Val Loss: 0.5789
# [resnet18] Epoch 12/12 Train Loss: 0.0361 Val Loss: 0.6281
# DR: best thr=0.65, val F1=0.7911
# Glaucoma: best thr=0.11, val F1=0.8000
# AMD: best thr=0.38, val F1=0.5195
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.001_bs64
# Average F1 over 3 diseases (offsite): 0.6875
#
# OFFSITE Average F1 for this config: 0.6875
# ============================================================
# Experiment 3: lr=0.0009, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3891 Val Loss: 1.4087
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2488 Val Loss: 2.4046
# [resnet18] Epoch 3/12 Train Loss: 0.1364 Val Loss: 0.5971
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.0810 Val Loss: 0.5754
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.0677 Val Loss: 0.5180
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 6/12 Train Loss: 0.0571 Val Loss: 0.5974
# [resnet18] Epoch 7/12 Train Loss: 0.0414 Val Loss: 0.8594
# [resnet18] Epoch 8/12 Train Loss: 0.0349 Val Loss: 0.6913
# [resnet18] Epoch 9/12 Train Loss: 0.0423 Val Loss: 0.8363
# [resnet18] Epoch 10/12 Train Loss: 0.0362 Val Loss: 0.6763
# [resnet18] Epoch 11/12 Train Loss: 0.0329 Val Loss: 0.7002
# [resnet18] Epoch 12/12 Train Loss: 0.0208 Val Loss: 0.6272
# DR: best thr=0.52, val F1=0.8160
# Glaucoma: best thr=0.25, val F1=0.7736
# AMD: best thr=0.15, val F1=0.6190
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0009_bs128
# Average F1 over 3 diseases (offsite): 0.7533
#
# OFFSITE Average F1 for this config: 0.7533
# ============================================================
# Experiment 4: lr=0.0009, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3825 Val Loss: 1.6849
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2281 Val Loss: 0.4121
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1667 Val Loss: 0.5446
# [resnet18] Epoch 4/12 Train Loss: 0.0848 Val Loss: 0.4947
# [resnet18] Epoch 5/12 Train Loss: 0.0536 Val Loss: 0.4014
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 6/12 Train Loss: 0.0506 Val Loss: 0.5405
# [resnet18] Epoch 7/12 Train Loss: 0.0435 Val Loss: 0.4824
# [resnet18] Epoch 8/12 Train Loss: 0.0400 Val Loss: 0.7712
# [resnet18] Epoch 9/12 Train Loss: 0.0473 Val Loss: 0.8965
# [resnet18] Epoch 10/12 Train Loss: 0.0362 Val Loss: 0.4957
# [resnet18] Epoch 11/12 Train Loss: 0.0389 Val Loss: 1.3645
# [resnet18] Epoch 12/12 Train Loss: 0.0398 Val Loss: 0.5685
# DR: best thr=0.66, val F1=0.8136
# Glaucoma: best thr=0.25, val F1=0.7857
# AMD: best thr=0.18, val F1=0.5789
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0009_bs64
# Average F1 over 3 diseases (offsite): 0.7291
#
# OFFSITE Average F1 for this config: 0.7291
# ============================================================
# Experiment 5: lr=0.0008, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3796 Val Loss: 2.1970
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2355 Val Loss: 0.5101
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.2025 Val Loss: 0.5802
# [resnet18] Epoch 4/12 Train Loss: 0.1136 Val Loss: 0.9007
# [resnet18] Epoch 5/12 Train Loss: 0.0571 Val Loss: 0.7466
# [resnet18] Epoch 6/12 Train Loss: 0.0486 Val Loss: 0.6264
# [resnet18] Epoch 7/12 Train Loss: 0.0368 Val Loss: 0.5064
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 8/12 Train Loss: 0.0317 Val Loss: 0.4995
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 9/12 Train Loss: 0.0250 Val Loss: 0.5315
# [resnet18] Epoch 10/12 Train Loss: 0.0178 Val Loss: 0.6278
# [resnet18] Epoch 11/12 Train Loss: 0.0178 Val Loss: 0.7386
# [resnet18] Epoch 12/12 Train Loss: 0.0137 Val Loss: 0.5354
# DR: best thr=0.67, val F1=0.8186
# Glaucoma: best thr=0.10, val F1=0.7863
# AMD: best thr=0.16, val F1=0.6452
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0008_bs128
# Average F1 over 3 diseases (offsite): 0.6959
#
# OFFSITE Average F1 for this config: 0.6959
# ============================================================
# Experiment 6: lr=0.0008, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3908 Val Loss: 0.9510
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2386 Val Loss: 0.8199
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1300 Val Loss: 0.4170
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.0750 Val Loss: 0.4766
# [resnet18] Epoch 5/12 Train Loss: 0.0770 Val Loss: 0.5472
# [resnet18] Epoch 6/12 Train Loss: 0.0551 Val Loss: 0.5694
# [resnet18] Epoch 7/12 Train Loss: 0.0589 Val Loss: 0.5907
# [resnet18] Epoch 8/12 Train Loss: 0.0532 Val Loss: 0.5801
# [resnet18] Epoch 9/12 Train Loss: 0.0429 Val Loss: 0.5466
# [resnet18] Epoch 10/12 Train Loss: 0.0444 Val Loss: 0.6032
# [resnet18] Epoch 11/12 Train Loss: 0.0273 Val Loss: 0.6265
# [resnet18] Epoch 12/12 Train Loss: 0.0196 Val Loss: 0.5323
# DR: best thr=0.72, val F1=0.8186
# Glaucoma: best thr=0.22, val F1=0.8148
# AMD: best thr=0.32, val F1=0.7027
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0008_bs64
# Average F1 over 3 diseases (offsite): 0.6976
#
# OFFSITE Average F1 for this config: 0.6976
# ============================================================
# Experiment 7: lr=0.0007, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3814 Val Loss: 1.2492
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2074 Val Loss: 0.5781
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1244 Val Loss: 1.7185
# [resnet18] Epoch 4/12 Train Loss: 0.0691 Val Loss: 0.4814
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.0473 Val Loss: 0.5519
# [resnet18] Epoch 6/12 Train Loss: 0.0327 Val Loss: 0.6575
# [resnet18] Epoch 7/12 Train Loss: 0.0286 Val Loss: 0.5655
# [resnet18] Epoch 8/12 Train Loss: 0.0154 Val Loss: 0.4895
# [resnet18] Epoch 9/12 Train Loss: 0.0131 Val Loss: 0.4918
# [resnet18] Epoch 10/12 Train Loss: 0.0135 Val Loss: 0.5393
# [resnet18] Epoch 11/12 Train Loss: 0.0112 Val Loss: 0.5609
# [resnet18] Epoch 12/12 Train Loss: 0.0170 Val Loss: 0.7066
# DR: best thr=0.46, val F1=0.8049
# Glaucoma: best thr=0.14, val F1=0.8000
# AMD: best thr=0.14, val F1=0.6353
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0007_bs128
# Average F1 over 3 diseases (offsite): 0.7480
#
# OFFSITE Average F1 for this config: 0.7480
# ============================================================
# Experiment 8: lr=0.0007, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3788 Val Loss: 0.9116
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.1959 Val Loss: 0.6459
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1178 Val Loss: 0.5742
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.0717 Val Loss: 0.3622
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.0385 Val Loss: 0.3990
# [resnet18] Epoch 6/12 Train Loss: 0.0264 Val Loss: 0.6658
# [resnet18] Epoch 7/12 Train Loss: 0.0350 Val Loss: 0.5368
# [resnet18] Epoch 8/12 Train Loss: 0.0394 Val Loss: 0.6293
# [resnet18] Epoch 9/12 Train Loss: 0.0345 Val Loss: 0.7496
# [resnet18] Epoch 10/12 Train Loss: 0.0281 Val Loss: 0.7030
# [resnet18] Epoch 11/12 Train Loss: 0.0254 Val Loss: 0.5428
# [resnet18] Epoch 12/12 Train Loss: 0.0394 Val Loss: 0.5724
# DR: best thr=0.57, val F1=0.8108
# Glaucoma: best thr=0.10, val F1=0.8000
# AMD: best thr=0.84, val F1=0.6818
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0007_bs64
# Average F1 over 3 diseases (offsite): 0.7812
#
# OFFSITE Average F1 for this config: 0.7812
# ============================================================
# Experiment 9: lr=0.0006, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3683 Val Loss: 0.6392
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.1770 Val Loss: 0.4572
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1089 Val Loss: 0.4405
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.0696 Val Loss: 0.6239
# [resnet18] Epoch 5/12 Train Loss: 0.0332 Val Loss: 0.5794
# [resnet18] Epoch 6/12 Train Loss: 0.0239 Val Loss: 0.5433
# [resnet18] Epoch 7/12 Train Loss: 0.0191 Val Loss: 0.5480
# [resnet18] Epoch 8/12 Train Loss: 0.0192 Val Loss: 0.5449
# [resnet18] Epoch 9/12 Train Loss: 0.0181 Val Loss: 0.5804
# [resnet18] Epoch 10/12 Train Loss: 0.0136 Val Loss: 0.5796
# [resnet18] Epoch 11/12 Train Loss: 0.0179 Val Loss: 0.5050
# [resnet18] Epoch 12/12 Train Loss: 0.0183 Val Loss: 0.5396
# DR: best thr=0.83, val F1=0.8089
# Glaucoma: best thr=0.12, val F1=0.7788
# AMD: best thr=0.15, val F1=0.6429
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0006_bs128
# Average F1 over 3 diseases (offsite): 0.7010
#
# OFFSITE Average F1 for this config: 0.7010
# ============================================================
# Experiment 10: lr=0.0006, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3724 Val Loss: 0.5678
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2241 Val Loss: 0.4856
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1376 Val Loss: 0.3992
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.0614 Val Loss: 0.6023
# [resnet18] Epoch 5/12 Train Loss: 0.0355 Val Loss: 0.5323
# [resnet18] Epoch 6/12 Train Loss: 0.0334 Val Loss: 0.5087
# [resnet18] Epoch 7/12 Train Loss: 0.0278 Val Loss: 0.6543
# [resnet18] Epoch 8/12 Train Loss: 0.0225 Val Loss: 0.5493
# [resnet18] Epoch 9/12 Train Loss: 0.0222 Val Loss: 0.4915
# [resnet18] Epoch 10/12 Train Loss: 0.0278 Val Loss: 0.7940
# [resnet18] Epoch 11/12 Train Loss: 0.0343 Val Loss: 0.8858
# [resnet18] Epoch 12/12 Train Loss: 0.0293 Val Loss: 0.6064
# DR: best thr=0.49, val F1=0.8035
# Glaucoma: best thr=0.10, val F1=0.7664
# AMD: best thr=0.57, val F1=0.6292
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0006_bs64
# Average F1 over 3 diseases (offsite): 0.7044
#
# OFFSITE Average F1 for this config: 0.7044
# ============================================================
# Experiment 11: lr=0.0005, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3598 Val Loss: 0.5483
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.1725 Val Loss: 0.4448
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.0974 Val Loss: 0.4691
# [resnet18] Epoch 4/12 Train Loss: 0.0526 Val Loss: 0.4085
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.0270 Val Loss: 0.4463
# [resnet18] Epoch 6/12 Train Loss: 0.0211 Val Loss: 0.3745
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 7/12 Train Loss: 0.0193 Val Loss: 0.4561
# [resnet18] Epoch 8/12 Train Loss: 0.0135 Val Loss: 0.6042
# [resnet18] Epoch 9/12 Train Loss: 0.0161 Val Loss: 0.5053
# [resnet18] Epoch 10/12 Train Loss: 0.0102 Val Loss: 0.4815
# [resnet18] Epoch 11/12 Train Loss: 0.0088 Val Loss: 0.5417
# [resnet18] Epoch 12/12 Train Loss: 0.0082 Val Loss: 0.5733
# DR: best thr=0.90, val F1=0.8069
# Glaucoma: best thr=0.13, val F1=0.7961
# AMD: best thr=0.10, val F1=0.7273
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0005_bs128
# Average F1 over 3 diseases (offsite): 0.7660
#
# OFFSITE Average F1 for this config: 0.7660
# ============================================================
# Experiment 12: lr=0.0005, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3597 Val Loss: 0.9679
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.1786 Val Loss: 0.4307
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.0987 Val Loss: 0.4244
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.0470 Val Loss: 0.4495
# [resnet18] Epoch 5/12 Train Loss: 0.0240 Val Loss: 0.4674
# [resnet18] Epoch 6/12 Train Loss: 0.0195 Val Loss: 0.5455
# [resnet18] Epoch 7/12 Train Loss: 0.0163 Val Loss: 0.5509
# [resnet18] Epoch 8/12 Train Loss: 0.0165 Val Loss: 0.6637
# [resnet18] Epoch 9/12 Train Loss: 0.0101 Val Loss: 0.5808
# [resnet18] Epoch 10/12 Train Loss: 0.0145 Val Loss: 0.5133
# [resnet18] Epoch 11/12 Train Loss: 0.0103 Val Loss: 0.4762
# [resnet18] Epoch 12/12 Train Loss: 0.0137 Val Loss: 0.5378
# DR: best thr=0.71, val F1=0.8225
# Glaucoma: best thr=0.10, val F1=0.8430
# AMD: best thr=0.77, val F1=0.6269
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0005_bs64
# Average F1 over 3 diseases (offsite): 0.7686
#
# OFFSITE Average F1 for this config: 0.7686
# ============================================================
# Experiment 13: lr=0.0004, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3807 Val Loss: 0.4572
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.1495 Val Loss: 0.4227
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.0781 Val Loss: 0.4483
# [resnet18] Epoch 4/12 Train Loss: 0.0391 Val Loss: 0.4070
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.0263 Val Loss: 0.4775
# [resnet18] Epoch 6/12 Train Loss: 0.0293 Val Loss: 0.5208
# [resnet18] Epoch 7/12 Train Loss: 0.0262 Val Loss: 0.5738
# [resnet18] Epoch 8/12 Train Loss: 0.0230 Val Loss: 0.6958
# [resnet18] Epoch 9/12 Train Loss: 0.0196 Val Loss: 0.5050
# [resnet18] Epoch 10/12 Train Loss: 0.0108 Val Loss: 0.5423
# [resnet18] Epoch 11/12 Train Loss: 0.0103 Val Loss: 0.5384
# [resnet18] Epoch 12/12 Train Loss: 0.0067 Val Loss: 0.5608
# DR: best thr=0.68, val F1=0.8462
# Glaucoma: best thr=0.11, val F1=0.8302
# AMD: best thr=0.10, val F1=0.6667
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0004_bs128
# Average F1 over 3 diseases (offsite): 0.7910
#
# OFFSITE Average F1 for this config: 0.7910
# ============================================================
# Experiment 14: lr=0.0004, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3585 Val Loss: 0.5643
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.1691 Val Loss: 0.4968
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.0727 Val Loss: 0.5393
# [resnet18] Epoch 4/12 Train Loss: 0.0397 Val Loss: 0.4795
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.0251 Val Loss: 0.4439
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 6/12 Train Loss: 0.0210 Val Loss: 0.5611
# [resnet18] Epoch 7/12 Train Loss: 0.0192 Val Loss: 0.4689
# [resnet18] Epoch 8/12 Train Loss: 0.0139 Val Loss: 0.4747
# [resnet18] Epoch 9/12 Train Loss: 0.0163 Val Loss: 0.6590
# [resnet18] Epoch 10/12 Train Loss: 0.0115 Val Loss: 0.5293
# [resnet18] Epoch 11/12 Train Loss: 0.0055 Val Loss: 0.4899
# [resnet18] Epoch 12/12 Train Loss: 0.0034 Val Loss: 0.4995
# DR: best thr=0.83, val F1=0.8559
# Glaucoma: best thr=0.28, val F1=0.8257
# AMD: best thr=0.15, val F1=0.7273
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0004_bs64
# Average F1 over 3 diseases (offsite): 0.7567
#
# OFFSITE Average F1 for this config: 0.7567
# ============================================================
# Experiment 15: lr=0.0003, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3843 Val Loss: 0.3889
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.1825 Val Loss: 0.4446
# [resnet18] Epoch 3/12 Train Loss: 0.0846 Val Loss: 0.4223
# [resnet18] Epoch 4/12 Train Loss: 0.0370 Val Loss: 0.3895
# [resnet18] Epoch 5/12 Train Loss: 0.0213 Val Loss: 0.4355
# [resnet18] Epoch 6/12 Train Loss: 0.0143 Val Loss: 0.4183
# [resnet18] Epoch 7/12 Train Loss: 0.0135 Val Loss: 0.4506
# [resnet18] Epoch 8/12 Train Loss: 0.0100 Val Loss: 0.4586
# [resnet18] Epoch 9/12 Train Loss: 0.0083 Val Loss: 0.5144
# [resnet18] Epoch 10/12 Train Loss: 0.0057 Val Loss: 0.5332
# [resnet18] Epoch 11/12 Train Loss: 0.0058 Val Loss: 0.4843
# [resnet18] Epoch 12/12 Train Loss: 0.0072 Val Loss: 0.5154
# DR: best thr=0.89, val F1=0.8319
# Glaucoma: best thr=0.10, val F1=0.8214
# AMD: best thr=0.50, val F1=0.6914
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0003_bs128
# Average F1 over 3 diseases (offsite): 0.7193
#
# OFFSITE Average F1 for this config: 0.7193
# ============================================================
# Experiment 16: lr=0.0003, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3590 Val Loss: 0.5266
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.1636 Val Loss: 0.4055
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.0725 Val Loss: 0.3851
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.0346 Val Loss: 0.5014
# [resnet18] Epoch 5/12 Train Loss: 0.0212 Val Loss: 0.4834
# [resnet18] Epoch 6/12 Train Loss: 0.0152 Val Loss: 0.4665
# [resnet18] Epoch 7/12 Train Loss: 0.0113 Val Loss: 0.5413
# [resnet18] Epoch 8/12 Train Loss: 0.0104 Val Loss: 0.4932
# [resnet18] Epoch 9/12 Train Loss: 0.0080 Val Loss: 0.4812
# [resnet18] Epoch 10/12 Train Loss: 0.0080 Val Loss: 0.5074
# [resnet18] Epoch 11/12 Train Loss: 0.0054 Val Loss: 0.4918
# [resnet18] Epoch 12/12 Train Loss: 0.0046 Val Loss: 0.5037
# DR: best thr=0.89, val F1=0.8520
# Glaucoma: best thr=0.13, val F1=0.8361
# AMD: best thr=0.12, val F1=0.7470
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0003_bs64
# Average F1 over 3 diseases (offsite): 0.7828
#
# OFFSITE Average F1 for this config: 0.7828
# ============================================================
# Experiment 17: lr=0.0002, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4045 Val Loss: 0.3818
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2014 Val Loss: 0.3795
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1085 Val Loss: 0.3697
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.0566 Val Loss: 0.3936
# [resnet18] Epoch 5/12 Train Loss: 0.0335 Val Loss: 0.3988
# [resnet18] Epoch 6/12 Train Loss: 0.0203 Val Loss: 0.3757
# [resnet18] Epoch 7/12 Train Loss: 0.0156 Val Loss: 0.4024
# [resnet18] Epoch 8/12 Train Loss: 0.0168 Val Loss: 0.4476
# [resnet18] Epoch 9/12 Train Loss: 0.0139 Val Loss: 0.5070
# [resnet18] Epoch 10/12 Train Loss: 0.0112 Val Loss: 0.4942
# [resnet18] Epoch 11/12 Train Loss: 0.0096 Val Loss: 0.4549
# [resnet18] Epoch 12/12 Train Loss: 0.0077 Val Loss: 0.4519
# DR: best thr=0.89, val F1=0.8349
# Glaucoma: best thr=0.16, val F1=0.8348
# AMD: best thr=0.11, val F1=0.7033
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0002_bs128
# Average F1 over 3 diseases (offsite): 0.7381
#
# OFFSITE Average F1 for this config: 0.7381
# ============================================================
# Experiment 18: lr=0.0002, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.3584 Val Loss: 0.3883
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.1548 Val Loss: 0.3419
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.0712 Val Loss: 0.3833
# [resnet18] Epoch 4/12 Train Loss: 0.0418 Val Loss: 0.3829
# [resnet18] Epoch 5/12 Train Loss: 0.0287 Val Loss: 0.5198
# [resnet18] Epoch 6/12 Train Loss: 0.0190 Val Loss: 0.4641
# [resnet18] Epoch 7/12 Train Loss: 0.0142 Val Loss: 0.4642
# [resnet18] Epoch 8/12 Train Loss: 0.0152 Val Loss: 0.4300
# [resnet18] Epoch 9/12 Train Loss: 0.0102 Val Loss: 0.4611
# [resnet18] Epoch 10/12 Train Loss: 0.0071 Val Loss: 0.4629
# [resnet18] Epoch 11/12 Train Loss: 0.0049 Val Loss: 0.4598
# [resnet18] Epoch 12/12 Train Loss: 0.0051 Val Loss: 0.4730
# DR: best thr=0.89, val F1=0.8468
# Glaucoma: best thr=0.21, val F1=0.8288
# AMD: best thr=0.45, val F1=0.7143
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0002_bs64
# Average F1 over 3 diseases (offsite): 0.7741
#
# OFFSITE Average F1 for this config: 0.7741
# ============================================================
# Experiment 19: lr=0.0001, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4327 Val Loss: 0.4124
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2639 Val Loss: 0.3810
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1798 Val Loss: 0.3610
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.1141 Val Loss: 0.3582
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.0730 Val Loss: 0.3663
# [resnet18] Epoch 6/12 Train Loss: 0.0460 Val Loss: 0.3731
# [resnet18] Epoch 7/12 Train Loss: 0.0278 Val Loss: 0.3867
# [resnet18] Epoch 8/12 Train Loss: 0.0199 Val Loss: 0.3974
# [resnet18] Epoch 9/12 Train Loss: 0.0155 Val Loss: 0.4016
# [resnet18] Epoch 10/12 Train Loss: 0.0156 Val Loss: 0.4094
# [resnet18] Epoch 11/12 Train Loss: 0.0146 Val Loss: 0.4017
# [resnet18] Epoch 12/12 Train Loss: 0.0103 Val Loss: 0.4279
# DR: best thr=0.76, val F1=0.8533
# Glaucoma: best thr=0.38, val F1=0.7925
# AMD: best thr=0.50, val F1=0.7160
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0001_bs128
# Average F1 over 3 diseases (offsite): 0.7814
#
# OFFSITE Average F1 for this config: 0.7814
# ============================================================
# Experiment 20: lr=0.0001, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4030 Val Loss: 0.3902
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2141 Val Loss: 0.3441
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1171 Val Loss: 0.3494
# [resnet18] Epoch 4/12 Train Loss: 0.0610 Val Loss: 0.3656
# [resnet18] Epoch 5/12 Train Loss: 0.0294 Val Loss: 0.3800
# [resnet18] Epoch 6/12 Train Loss: 0.0193 Val Loss: 0.4034
# [resnet18] Epoch 7/12 Train Loss: 0.0155 Val Loss: 0.4312
# [resnet18] Epoch 8/12 Train Loss: 0.0124 Val Loss: 0.4276
# [resnet18] Epoch 9/12 Train Loss: 0.0152 Val Loss: 0.4291
# [resnet18] Epoch 10/12 Train Loss: 0.0125 Val Loss: 0.4440
# [resnet18] Epoch 11/12 Train Loss: 0.0093 Val Loss: 0.4432
# [resnet18] Epoch 12/12 Train Loss: 0.0069 Val Loss: 0.4403
# DR: best thr=0.77, val F1=0.8448
# Glaucoma: best thr=0.10, val F1=0.8000
# AMD: best thr=0.25, val F1=0.7253
#
# OFFSITE test results for resnet18 - full_ft_cb_lr0.0001_bs64
# Average F1 over 3 diseases (offsite): 0.7518
#
# OFFSITE Average F1 for this config: 0.7518
# ============================================================
# Experiment 21: lr=9e-05, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4391 Val Loss: 0.4073
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2817 Val Loss: 0.3741
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1967 Val Loss: 0.3573
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.1331 Val Loss: 0.3585
# [resnet18] Epoch 5/12 Train Loss: 0.0858 Val Loss: 0.3581
# [resnet18] Epoch 6/12 Train Loss: 0.0556 Val Loss: 0.3717
# [resnet18] Epoch 7/12 Train Loss: 0.0366 Val Loss: 0.3734
# [resnet18] Epoch 8/12 Train Loss: 0.0269 Val Loss: 0.3748
# [resnet18] Epoch 9/12 Train Loss: 0.0192 Val Loss: 0.3863
# [resnet18] Epoch 10/12 Train Loss: 0.0147 Val Loss: 0.3936
# [resnet18] Epoch 11/12 Train Loss: 0.0136 Val Loss: 0.3918
# [resnet18] Epoch 12/12 Train Loss: 0.0101 Val Loss: 0.4080
# DR: best thr=0.79, val F1=0.8696
# Glaucoma: best thr=0.20, val F1=0.8288
# AMD: best thr=0.23, val F1=0.7126
#
# OFFSITE test results for resnet18 - full_ft_cb_lr9e-05_bs128
# Average F1 over 3 diseases (offsite): 0.7612
#
# OFFSITE Average F1 for this config: 0.7612
# ============================================================
# Experiment 22: lr=9e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4192 Val Loss: 0.3910
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2317 Val Loss: 0.3487
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1369 Val Loss: 0.3499
# [resnet18] Epoch 4/12 Train Loss: 0.0699 Val Loss: 0.3676
# [resnet18] Epoch 5/12 Train Loss: 0.0360 Val Loss: 0.3784
# [resnet18] Epoch 6/12 Train Loss: 0.0222 Val Loss: 0.3947
# [resnet18] Epoch 7/12 Train Loss: 0.0163 Val Loss: 0.4121
# [resnet18] Epoch 8/12 Train Loss: 0.0128 Val Loss: 0.4361
# [resnet18] Epoch 9/12 Train Loss: 0.0116 Val Loss: 0.4458
# [resnet18] Epoch 10/12 Train Loss: 0.0101 Val Loss: 0.4337
# [resnet18] Epoch 11/12 Train Loss: 0.0108 Val Loss: 0.4371
# [resnet18] Epoch 12/12 Train Loss: 0.0100 Val Loss: 0.4794
# DR: best thr=0.90, val F1=0.8609
# Glaucoma: best thr=0.20, val F1=0.8000
# AMD: best thr=0.18, val F1=0.7294
#
# OFFSITE test results for resnet18 - full_ft_cb_lr9e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7666
#
# OFFSITE Average F1 for this config: 0.7666
# ============================================================
# Experiment 23: lr=8e-05, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4438 Val Loss: 0.4221
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2947 Val Loss: 0.3758
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.2110 Val Loss: 0.3580
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.1462 Val Loss: 0.3479
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.1026 Val Loss: 0.3490
# [resnet18] Epoch 6/12 Train Loss: 0.0678 Val Loss: 0.3583
# [resnet18] Epoch 7/12 Train Loss: 0.0432 Val Loss: 0.3874
# [resnet18] Epoch 8/12 Train Loss: 0.0364 Val Loss: 0.3722
# [resnet18] Epoch 9/12 Train Loss: 0.0237 Val Loss: 0.3888
# [resnet18] Epoch 10/12 Train Loss: 0.0198 Val Loss: 0.3961
# [resnet18] Epoch 11/12 Train Loss: 0.0159 Val Loss: 0.4067
# [resnet18] Epoch 12/12 Train Loss: 0.0137 Val Loss: 0.4052
# DR: best thr=0.79, val F1=0.8533
# Glaucoma: best thr=0.15, val F1=0.7899
# AMD: best thr=0.17, val F1=0.7174
#
# OFFSITE test results for resnet18 - full_ft_cb_lr8e-05_bs128
# Average F1 over 3 diseases (offsite): 0.7689
#
# OFFSITE Average F1 for this config: 0.7689
# ============================================================
# Experiment 24: lr=8e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4145 Val Loss: 0.3980
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2400 Val Loss: 0.3567
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1480 Val Loss: 0.3509
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.0852 Val Loss: 0.3616
# [resnet18] Epoch 5/12 Train Loss: 0.0491 Val Loss: 0.3825
# [resnet18] Epoch 6/12 Train Loss: 0.0299 Val Loss: 0.3771
# [resnet18] Epoch 7/12 Train Loss: 0.0214 Val Loss: 0.3973
# [resnet18] Epoch 8/12 Train Loss: 0.0174 Val Loss: 0.3944
# [resnet18] Epoch 9/12 Train Loss: 0.0159 Val Loss: 0.4086
# [resnet18] Epoch 10/12 Train Loss: 0.0140 Val Loss: 0.4419
# [resnet18] Epoch 11/12 Train Loss: 0.0106 Val Loss: 0.4376
# [resnet18] Epoch 12/12 Train Loss: 0.0091 Val Loss: 0.4442
# DR: best thr=0.82, val F1=0.8522
# Glaucoma: best thr=0.25, val F1=0.8036
# AMD: best thr=0.15, val F1=0.7045
#
# OFFSITE test results for resnet18 - full_ft_cb_lr8e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7532
#
# OFFSITE Average F1 for this config: 0.7532
# ============================================================
# Experiment 25: lr=7e-05, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4494 Val Loss: 0.4171
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.3095 Val Loss: 0.3791
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.2405 Val Loss: 0.3655
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.1743 Val Loss: 0.3545
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.1280 Val Loss: 0.3544
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 6/12 Train Loss: 0.0908 Val Loss: 0.3691
# [resnet18] Epoch 7/12 Train Loss: 0.0634 Val Loss: 0.3734
# [resnet18] Epoch 8/12 Train Loss: 0.0462 Val Loss: 0.3768
# [resnet18] Epoch 9/12 Train Loss: 0.0332 Val Loss: 0.3800
# [resnet18] Epoch 10/12 Train Loss: 0.0245 Val Loss: 0.3829
# [resnet18] Epoch 11/12 Train Loss: 0.0187 Val Loss: 0.3904
# [resnet18] Epoch 12/12 Train Loss: 0.0159 Val Loss: 0.4034
# DR: best thr=0.67, val F1=0.8498
# Glaucoma: best thr=0.57, val F1=0.7921
# AMD: best thr=0.19, val F1=0.6875
#
# OFFSITE test results for resnet18 - full_ft_cb_lr7e-05_bs128
# Average F1 over 3 diseases (offsite): 0.7629
#
# OFFSITE Average F1 for this config: 0.7629
# ============================================================
# Experiment 26: lr=7e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4295 Val Loss: 0.3904
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2612 Val Loss: 0.3549
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1694 Val Loss: 0.3468
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.1046 Val Loss: 0.3563
# [resnet18] Epoch 5/12 Train Loss: 0.0594 Val Loss: 0.3635
# [resnet18] Epoch 6/12 Train Loss: 0.0371 Val Loss: 0.3781
# [resnet18] Epoch 7/12 Train Loss: 0.0256 Val Loss: 0.3872
# [resnet18] Epoch 8/12 Train Loss: 0.0182 Val Loss: 0.4126
# [resnet18] Epoch 9/12 Train Loss: 0.0157 Val Loss: 0.4193
# [resnet18] Epoch 10/12 Train Loss: 0.0141 Val Loss: 0.4286
# [resnet18] Epoch 11/12 Train Loss: 0.0126 Val Loss: 0.4231
# [resnet18] Epoch 12/12 Train Loss: 0.0116 Val Loss: 0.4284
# DR: best thr=0.76, val F1=0.8658
# Glaucoma: best thr=0.21, val F1=0.8067
# AMD: best thr=0.18, val F1=0.7253
#
# OFFSITE test results for resnet18 - full_ft_cb_lr7e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7435
#
# OFFSITE Average F1 for this config: 0.7435
# ============================================================
# Experiment 27: lr=6e-05, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4500 Val Loss: 0.4315
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.3240 Val Loss: 0.3915
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.2527 Val Loss: 0.3671
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.1877 Val Loss: 0.3558
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.1424 Val Loss: 0.3501
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 6/12 Train Loss: 0.1065 Val Loss: 0.3499
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 7/12 Train Loss: 0.0799 Val Loss: 0.3540
# [resnet18] Epoch 8/12 Train Loss: 0.0559 Val Loss: 0.3609
# [resnet18] Epoch 9/12 Train Loss: 0.0393 Val Loss: 0.3703
# [resnet18] Epoch 10/12 Train Loss: 0.0298 Val Loss: 0.3826
# [resnet18] Epoch 11/12 Train Loss: 0.0257 Val Loss: 0.3974
# [resnet18] Epoch 12/12 Train Loss: 0.0198 Val Loss: 0.3961
# DR: best thr=0.73, val F1=0.8646
# Glaucoma: best thr=0.32, val F1=0.7850
# AMD: best thr=0.28, val F1=0.6747
#
# OFFSITE test results for resnet18 - full_ft_cb_lr6e-05_bs128
# Average F1 over 3 diseases (offsite): 0.7483
#
# OFFSITE Average F1 for this config: 0.7483
# ============================================================
# Experiment 28: lr=6e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4314 Val Loss: 0.3965
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2761 Val Loss: 0.3649
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.1888 Val Loss: 0.3480
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.1205 Val Loss: 0.3480
# [resnet18] Epoch 5/12 Train Loss: 0.0734 Val Loss: 0.3564
# [resnet18] Epoch 6/12 Train Loss: 0.0517 Val Loss: 0.3757
# [resnet18] Epoch 7/12 Train Loss: 0.0310 Val Loss: 0.3861
# [resnet18] Epoch 8/12 Train Loss: 0.0230 Val Loss: 0.3843
# [resnet18] Epoch 9/12 Train Loss: 0.0185 Val Loss: 0.4028
# [resnet18] Epoch 10/12 Train Loss: 0.0163 Val Loss: 0.4033
# [resnet18] Epoch 11/12 Train Loss: 0.0139 Val Loss: 0.4308
# [resnet18] Epoch 12/12 Train Loss: 0.0120 Val Loss: 0.4448
# DR: best thr=0.87, val F1=0.8482
# Glaucoma: best thr=0.10, val F1=0.7769
# AMD: best thr=0.15, val F1=0.7333
#
# OFFSITE test results for resnet18 - full_ft_cb_lr6e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7608
#
# OFFSITE Average F1 for this config: 0.7608
# ============================================================
# Experiment 29: lr=5e-05, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4616 Val Loss: 0.4330
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.3403 Val Loss: 0.4020
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.2673 Val Loss: 0.3781
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.2152 Val Loss: 0.3661
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.1714 Val Loss: 0.3594
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 6/12 Train Loss: 0.1353 Val Loss: 0.3557
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 7/12 Train Loss: 0.1026 Val Loss: 0.3576
# [resnet18] Epoch 8/12 Train Loss: 0.0799 Val Loss: 0.3661
# [resnet18] Epoch 9/12 Train Loss: 0.0591 Val Loss: 0.3662
# [resnet18] Epoch 10/12 Train Loss: 0.0456 Val Loss: 0.3701
# [resnet18] Epoch 11/12 Train Loss: 0.0380 Val Loss: 0.3799
# [resnet18] Epoch 12/12 Train Loss: 0.0311 Val Loss: 0.3868
# DR: best thr=0.69, val F1=0.8684
# Glaucoma: best thr=0.17, val F1=0.7899
# AMD: best thr=0.28, val F1=0.6966
#
# OFFSITE test results for resnet18 - full_ft_cb_lr5e-05_bs128
# Average F1 over 3 diseases (offsite): 0.7717
#
# OFFSITE Average F1 for this config: 0.7717
# ============================================================
# Experiment 30: lr=5e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4390 Val Loss: 0.4129
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.2896 Val Loss: 0.3686
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.2133 Val Loss: 0.3598
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.1425 Val Loss: 0.3537
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.0972 Val Loss: 0.3620
# [resnet18] Epoch 6/12 Train Loss: 0.0668 Val Loss: 0.3699
# [resnet18] Epoch 7/12 Train Loss: 0.0453 Val Loss: 0.3833
# [resnet18] Epoch 8/12 Train Loss: 0.0320 Val Loss: 0.3885
# [resnet18] Epoch 9/12 Train Loss: 0.0255 Val Loss: 0.3999
# [resnet18] Epoch 10/12 Train Loss: 0.0212 Val Loss: 0.4015
# [resnet18] Epoch 11/12 Train Loss: 0.0158 Val Loss: 0.4188
# [resnet18] Epoch 12/12 Train Loss: 0.0131 Val Loss: 0.4361
# DR: best thr=0.80, val F1=0.8571
# Glaucoma: best thr=0.10, val F1=0.7705
# AMD: best thr=0.26, val F1=0.6829
#
# OFFSITE test results for resnet18 - full_ft_cb_lr5e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7536
#
# OFFSITE Average F1 for this config: 0.7536
# ============================================================
# ...
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 7/12 Train Loss: 0.1354 Val Loss: 0.3586
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 8/12 Train Loss: 0.1116 Val Loss: 0.3578
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 9/12 Train Loss: 0.0902 Val Loss: 0.3620
# [resnet18] Epoch 10/12 Train Loss: 0.0699 Val Loss: 0.3673
# [resnet18] Epoch 11/12 Train Loss: 0.0569 Val Loss: 0.3731
# [resnet18] Epoch 12/12 Train Loss: 0.0473 Val Loss: 0.3771
# DR: best thr=0.72, val F1=0.8649
# Glaucoma: best thr=0.33, val F1=0.7857
# AMD: best thr=0.27, val F1=0.6667
#
# OFFSITE test results for resnet18 - full_ft_cb_lr4e-05_bs128
# Average F1 over 3 diseases (offsite): 0.7655
#
# OFFSITE Average F1 for this config: 0.7655
# ============================================================
# Experiment 32: lr=4e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4436 Val Loss: 0.4139
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.3160 Val Loss: 0.3819
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.2343 Val Loss: 0.3604
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.1823 Val Loss: 0.3537
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.1326 Val Loss: 0.3587
# [resnet18] Epoch 6/12 Train Loss: 0.0936 Val Loss: 0.3702
# [resnet18] Epoch 7/12 Train Loss: 0.0694 Val Loss: 0.3758
# [resnet18] Epoch 8/12 Train Loss: 0.0501 Val Loss: 0.3858
# [resnet18] Epoch 9/12 Train Loss: 0.0362 Val Loss: 0.3916
# [resnet18] Epoch 10/12 Train Loss: 0.0280 Val Loss: 0.4012
# [resnet18] Epoch 11/12 Train Loss: 0.0235 Val Loss: 0.4134
# [resnet18] Epoch 12/12 Train Loss: 0.0206 Val Loss: 0.4159
# DR: best thr=0.69, val F1=0.8522
# Glaucoma: best thr=0.16, val F1=0.7769
# AMD: best thr=0.18, val F1=0.7021
#
# OFFSITE test results for resnet18 - full_ft_cb_lr4e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7531
#
# OFFSITE Average F1 for this config: 0.7531
# ============================================================
# Experiment 33: lr=3e-05, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4734 Val Loss: 0.4619
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.3892 Val Loss: 0.4262
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.3336 Val Loss: 0.3993
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.2898 Val Loss: 0.3840
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.2504 Val Loss: 0.3748
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 6/12 Train Loss: 0.2153 Val Loss: 0.3669
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 7/12 Train Loss: 0.1834 Val Loss: 0.3603
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 8/12 Train Loss: 0.1588 Val Loss: 0.3589
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 9/12 Train Loss: 0.1371 Val Loss: 0.3598
# [resnet18] Epoch 10/12 Train Loss: 0.1164 Val Loss: 0.3626
# [resnet18] Epoch 11/12 Train Loss: 0.0977 Val Loss: 0.3631
# [resnet18] Epoch 12/12 Train Loss: 0.0844 Val Loss: 0.3673
# DR: best thr=0.72, val F1=0.8426
# Glaucoma: best thr=0.40, val F1=0.7890
# AMD: best thr=0.26, val F1=0.6422
#
# OFFSITE test results for resnet18 - full_ft_cb_lr3e-05_bs128
# Average F1 over 3 diseases (offsite): 0.7664
#
# OFFSITE Average F1 for this config: 0.7664
# ============================================================
# Experiment 34: lr=3e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4536 Val Loss: 0.4377
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.3455 Val Loss: 0.3933
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.2750 Val Loss: 0.3714
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.2221 Val Loss: 0.3608
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.1809 Val Loss: 0.3534
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 6/12 Train Loss: 0.1425 Val Loss: 0.3569
# [resnet18] Epoch 7/12 Train Loss: 0.1101 Val Loss: 0.3581
# [resnet18] Epoch 8/12 Train Loss: 0.0915 Val Loss: 0.3645
# [resnet18] Epoch 9/12 Train Loss: 0.0676 Val Loss: 0.3738
# [resnet18] Epoch 10/12 Train Loss: 0.0486 Val Loss: 0.3796
# [resnet18] Epoch 11/12 Train Loss: 0.0410 Val Loss: 0.3801
# [resnet18] Epoch 12/12 Train Loss: 0.0320 Val Loss: 0.3902
# DR: best thr=0.72, val F1=0.8571
# Glaucoma: best thr=0.41, val F1=0.7810
# AMD: best thr=0.42, val F1=0.6914
#
# OFFSITE test results for resnet18 - full_ft_cb_lr3e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7640
#
# OFFSITE Average F1 for this config: 0.7640
# ============================================================
# Experiment 35: lr=2e-05, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4817 Val Loss: 0.4762
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.4218 Val Loss: 0.4476
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.3757 Val Loss: 0.4266
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.3411 Val Loss: 0.4079
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.3128 Val Loss: 0.3958
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 6/12 Train Loss: 0.2798 Val Loss: 0.3850
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 7/12 Train Loss: 0.2574 Val Loss: 0.3755
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 8/12 Train Loss: 0.2296 Val Loss: 0.3707
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 9/12 Train Loss: 0.2109 Val Loss: 0.3661
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 10/12 Train Loss: 0.1900 Val Loss: 0.3626
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 11/12 Train Loss: 0.1693 Val Loss: 0.3611
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 12/12 Train Loss: 0.1565 Val Loss: 0.3619
# DR: best thr=0.61, val F1=0.8376
# Glaucoma: best thr=0.41, val F1=0.7928
# AMD: best thr=0.39, val F1=0.6444
#
# OFFSITE test results for resnet18 - full_ft_cb_lr2e-05_bs128
# Average F1 over 3 diseases (offsite): 0.7493
#
# OFFSITE Average F1 for this config: 0.7493
# ============================================================
# Experiment 36: lr=2e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4724 Val Loss: 0.4555
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.3889 Val Loss: 0.4208
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.3325 Val Loss: 0.3973
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.2889 Val Loss: 0.3809
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.2517 Val Loss: 0.3681
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 6/12 Train Loss: 0.2136 Val Loss: 0.3616
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 7/12 Train Loss: 0.1821 Val Loss: 0.3617
# [resnet18] Epoch 8/12 Train Loss: 0.1575 Val Loss: 0.3605
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 9/12 Train Loss: 0.1329 Val Loss: 0.3626
# [resnet18] Epoch 10/12 Train Loss: 0.1094 Val Loss: 0.3639
# [resnet18] Epoch 11/12 Train Loss: 0.0936 Val Loss: 0.3685
# [resnet18] Epoch 12/12 Train Loss: 0.0769 Val Loss: 0.3717
# DR: best thr=0.69, val F1=0.8458
# Glaucoma: best thr=0.31, val F1=0.7890
# AMD: best thr=0.36, val F1=0.6522
#
# OFFSITE test results for resnet18 - full_ft_cb_lr2e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7424
#
# OFFSITE Average F1 for this config: 0.7424
# ============================================================
# Experiment 37: lr=1e-05, batch_size=128
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4897 Val Loss: 0.4907
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.4562 Val Loss: 0.4735
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.4346 Val Loss: 0.4598
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.4055 Val Loss: 0.4454
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.3849 Val Loss: 0.4345
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 6/12 Train Loss: 0.3631 Val Loss: 0.4237
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 7/12 Train Loss: 0.3465 Val Loss: 0.4144
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 8/12 Train Loss: 0.3284 Val Loss: 0.4054
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 9/12 Train Loss: 0.3123 Val Loss: 0.3981
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 10/12 Train Loss: 0.2984 Val Loss: 0.3936
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 11/12 Train Loss: 0.2849 Val Loss: 0.3855
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 12/12 Train Loss: 0.2704 Val Loss: 0.3823
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# DR: best thr=0.59, val F1=0.8376
# Glaucoma: best thr=0.37, val F1=0.8034
# AMD: best thr=0.47, val F1=0.6506
#
# OFFSITE test results for resnet18 - full_ft_cb_lr1e-05_bs128
# Average F1 over 3 diseases (offsite): 0.7438
#
# OFFSITE Average F1 for this config: 0.7438
# ============================================================
# Experiment 38: lr=1e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_resnet18.pt
# [resnet18] Epoch 1/12 Train Loss: 0.4854 Val Loss: 0.4845
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/12 Train Loss: 0.4367 Val Loss: 0.4541
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/12 Train Loss: 0.3989 Val Loss: 0.4342
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/12 Train Loss: 0.3675 Val Loss: 0.4164
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/12 Train Loss: 0.3402 Val Loss: 0.4012
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 6/12 Train Loss: 0.3128 Val Loss: 0.3923
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 7/12 Train Loss: 0.2916 Val Loss: 0.3846
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 8/12 Train Loss: 0.2682 Val Loss: 0.3771
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 9/12 Train Loss: 0.2494 Val Loss: 0.3722
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 10/12 Train Loss: 0.2357 Val Loss: 0.3687
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 11/12 Train Loss: 0.2138 Val Loss: 0.3673
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 12/12 Train Loss: 0.1969 Val Loss: 0.3666
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# DR: best thr=0.59, val F1=0.8354
# Glaucoma: best thr=0.33, val F1=0.8000
# AMD: best thr=0.44, val F1=0.6429
#
# OFFSITE test results for resnet18 - full_ft_cb_lr1e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7403
#
# OFFSITE Average F1 for this config: 0.7403
#
# ############################################################
# TOP 3 CONFIGURATIONS (by OFFSITE average F1)
# ############################################################
# Rank 1: avg_F1=0.7910, lr=0.0004, batch_size=128, ckpt=checkpoints\csu_task2_2_resnet18.pt
# Rank 2: avg_F1=0.7828, lr=0.0003, batch_size=64, ckpt=checkpoints\csu_task2_2_resnet18.pt
# Rank 3: avg_F1=0.7814, lr=0.0001, batch_size=128, ckpt=checkpoints\csu_task2_2_resnet18.pt
#
# ------------------------------------------------------------
# Generating Kaggle submission for TOP 1 model...
# Hyperparams: lr=0.0004, batch_size=128
# Kaggle submission saved to: submission\submission_task2_2_top1_resnet18_lr0.0004_bs128.csv
#
# ------------------------------------------------------------
# Generating Kaggle submission for TOP 2 model...
# Hyperparams: lr=0.0003, batch_size=64
# Kaggle submission saved to: submission\submission_task2_2_top2_resnet18_lr0.0003_bs64.csv
#
# ------------------------------------------------------------
# Generating Kaggle submission for TOP 3 model...
# Hyperparams: lr=0.0001, batch_size=128
# Kaggle submission saved to: submission\submission_task2_2_top3_resnet18_lr0.0001_bs128.csv
#
# Done. Top-3 models and Kaggle submissions generated.

# %%
# Task 2.2  resnet18, cb

backbone = "resnet18" 

if backbone == "resnet18":
    pretrained_path = pretrained_resnet18
elif backbone == "efficientnet":
    pretrained_path = pretrained_efficient
else:
    raise ValueError("unknown backbone")
    
checkpoint = "./checkpoints/task1/csu_task1_2_resnet18.pt"
#offsite
ckpt_task21, y_true_offsite, y_pred_offsite, val_probs, val_labels = train_one_backbone(
    backbone=backbone,
    train_csv=train_csv,
    val_csv=val_csv,
    test_csv=offsite_test_csv,
    train_image_dir=train_img_dir,
    val_image_dir=val_img_dir,
    test_image_dir=offsite_img_dir,
    epochs=10,
    batch_size=128,
    lr=0.0004,
    img_size=img_size,
    save_dir=save_dir,
    pretrained_backbone=pretrained_resnet18,
    task="full_ft",
    loss="cb", 
)


best_thrs = find_best_thresholds(val_probs, val_labels)

#onsite
generate_kaggle_submission(
    backbone=backbone,
    ckpt_path=ckpt_task21,
    onsite_csv=onsite_csv,          
    onsite_image_dir=onsite_img_dir,
    img_size=img_size,
    batch_size=batch_size,
    out_csv=f"submission_{backbone}_task2_2.csv",
    threshold = 0.5,
    best = False,
)

df_offsite = evaluating_metrics(
    y_true=y_true_offsite,
    y_pred=y_pred_offsite,
    backbone=backbone,
    task_name="full_ft",
    split_name="offsite",
)


torch.cuda.empty_cache()
df_offsite
# Out:
# cuda
# ===========================================
# Task 2 |  Backbone: resnet18 | loss: cb
# ===========================================
# Loaded pretrained weights from ./pretrained_backbone/ckpt_resnet18_ep50.pt
# [resnet18] Epoch 1/10 Train Loss: 0.6216 Val Loss: 1.4709
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 2/10 Train Loss: 0.2490 Val Loss: 0.6878
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 3/10 Train Loss: 0.1555 Val Loss: 0.3907
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 4/10 Train Loss: 0.0824 Val Loss: 0.3775
# Saved best model for resnet18 (full_ft) at checkpoints\csu_task2_2_resnet18.pt
# [resnet18] Epoch 5/10 Train Loss: 0.0471 Val Loss: 0.3842
# [resnet18] Epoch 6/10 Train Loss: 0.0284 Val Loss: 0.4464
# [resnet18] Epoch 7/10 Train Loss: 0.0169 Val Loss: 0.5416
# [resnet18] Epoch 8/10 Train Loss: 0.0128 Val Loss: 0.5124
# [resnet18] Epoch 9/10 Train Loss: 0.0096 Val Loss: 0.5084
# [resnet18] Epoch 10/10 Train Loss: 0.0097 Val Loss: 0.5875
# DR: best thr=0.90, val F1=0.8225
# Glaucoma: best thr=0.28, val F1=0.7843
# AMD: best thr=0.38, val F1=0.6486
# Kaggle submission saved to: submission\submission_resnet18_task2_2.csv
#
# OFFSITE test results for resnet18 - full_ft
# Average F1 over 3 diseases (offsite): 0.7763
#    Backbone     Task    Split     Disease  Accuracy  Precision    Recall  \
# 0  resnet18  full_ft  offsite          DR     0.840   0.855263  0.928571
# 1  resnet18  full_ft  offsite    Glaucoma     0.880   0.820513  0.653061
# 2  resnet18  full_ft  offsite         AMD     0.935   0.695652  0.727273
# 3  resnet18  full_ft  offsite  Average F1       NaN        NaN       NaN
#
#    F1-score     Kappa
# 0  0.890411  0.595960
# 1  0.727273  0.651619
# 2  0.711111  0.674512
# 3  0.776265       NaN

# %%
# task 2.2 efficientnet, try different hyperparameters to find the best ones
# No need to run this unless you are interested, though the pre result are preserved here just to show exploration process.
"""import gc

backbone = "efficientnet"
checkpoint = "./checkpoints/task1/csu_task1_2_efficientnet.pt"  # starting checkpoint for full_ft

if backbone == "resnet18":
    pretrained_path = pretrained_resnet18
elif backbone == "efficientnet":
    pretrained_path = pretrained_efficient
else:
    raise ValueError("unknown backbone")

# -------------------------
# Hyperparameter grids
# -------------------------
lrs = [
    1e-3, 9e-4, 8e-4, 7e-4, 6e-4, 5e-4, 4e-4, 3e-4, 2e-4, 1e-4,
    9e-5, 8e-5, 7e-5, 6e-5, 5e-5, 4e-5, 3e-5, 2e-5, 1e-5
]
batch_sizes = [64, 32]

results = []  # will store dicts with ckpt_path, avg_f1, and hyperparams

exp_id = 0

for lr in lrs:
    for batch_size in batch_sizes:
        exp_id += 1
        print("=" * 60)
        print(f"Experiment {exp_id}: lr={lr}, batch_size={batch_size}")
        print("=" * 60)

        # ---- Train with given hyperparameters ----
        ckpt_path, y_true_offsite, y_pred_offsite, val_probs, val_labels = train_one_backbone(
            backbone=backbone,
            train_csv=train_csv,
            val_csv=val_csv,
            test_csv=offsite_test_csv,
            train_image_dir=train_img_dir,
            val_image_dir=val_img_dir,
            test_image_dir=offsite_img_dir,
            epochs=12,
            batch_size=batch_size,
            lr=lr,
            img_size=img_size,
            save_dir=save_dir,
            pretrained_backbone=checkpoint,  # or pretrained_path if you prefer
            task="full_ft",
            loss="cb",   # class-balanced loss, no alpha/gamma needed
        )

        # ---- Compute validation-based thresholds (for later use on onsite) ----
        best_thrs = find_best_thresholds(val_probs, val_labels)

        # ---- Compute OFFSITE metrics (used to rank models) ----
        df_off = evaluating_metrics(
            y_true=y_true_offsite,
            y_pred=y_pred_offsite,
            backbone=backbone,
            task_name=f"full_ft_cb_lr{lr}_bs{batch_size}",
            split_name="offsite",
        )

        # Extract average F1 row (assuming your df has 'Disease' == 'Average F1')
        try:
            avg_f1 = df_off.loc[df_off["Disease"] == "Average F1", "F1-score"].values[0]
        except Exception as e:
            print("WARNING: Could not extract average F1 from df_off, defaulting to 0.0")
            print("Error:", e)
            avg_f1 = 0.0

        print(f"OFFSITE Average F1 for this config: {avg_f1:.4f}")

        # ---- Store result ----
        results.append(
            {
                "ckpt_path": ckpt_path,
                "avg_f1": float(avg_f1),
                "lr": lr,
                "batch_size": batch_size,
                "best_thrs": best_thrs,
            }
        )

        # ---- Clean up GPU memory ----
        del y_true_offsite, y_pred_offsite, val_probs, val_labels
        gc.collect()
        torch.cuda.empty_cache()

# -------------------------
# Select top 3 configurations
# -------------------------
results_sorted = sorted(results, key=lambda x: x["avg_f1"], reverse=True)
top3 = results_sorted[:3]

print("\n" + "#" * 60)
print("TOP 3 CONFIGURATIONS (by OFFSITE average F1)")
print("#" * 60)

for rank, r in enumerate(top3, start=1):
    print(
        f"Rank {rank}: avg_F1={r['avg_f1']:.4f}, "
        f"lr={r['lr']}, batch_size={r['batch_size']}, "
        f"ckpt={r['ckpt_path']}"
    )

"""
# Out:
# ============================================================
# Experiment 1: lr=0.001, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3563 Val Loss: 0.4153
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1859 Val Loss: 0.4633
# [efficientnet] Epoch 3/12 Train Loss: 0.1064 Val Loss: 0.5348
# [efficientnet] Epoch 4/12 Train Loss: 0.0540 Val Loss: 0.5947
# [efficientnet] Epoch 5/12 Train Loss: 0.0520 Val Loss: 0.7034
# [efficientnet] Epoch 6/12 Train Loss: 0.0496 Val Loss: 0.5380
# [efficientnet] Epoch 7/12 Train Loss: 0.0353 Val Loss: 0.5433
# [efficientnet] Epoch 8/12 Train Loss: 0.0341 Val Loss: 0.6265
# [efficientnet] Epoch 9/12 Train Loss: 0.0299 Val Loss: 0.5302
# [efficientnet] Epoch 10/12 Train Loss: 0.0283 Val Loss: 0.5359
# [efficientnet] Epoch 11/12 Train Loss: 0.0165 Val Loss: 0.7011
# [efficientnet] Epoch 12/12 Train Loss: 0.0153 Val Loss: 0.5916
# DR: best thr=0.71, val F1=0.8509
# Glaucoma: best thr=0.33, val F1=0.8073
# AMD: best thr=0.10, val F1=0.7089
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.001_bs64
# Average F1 over 3 diseases (offsite): 0.6829
#
# OFFSITE Average F1 for this config: 0.6829
# ============================================================
# Experiment 2: lr=0.001, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3678 Val Loss: 0.4737
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1996 Val Loss: 0.6082
# [efficientnet] Epoch 3/12 Train Loss: 0.1188 Val Loss: 0.5708
# [efficientnet] Epoch 4/12 Train Loss: 0.0823 Val Loss: 0.5808
# [efficientnet] Epoch 5/12 Train Loss: 0.0774 Val Loss: 0.5520
# [efficientnet] Epoch 6/12 Train Loss: 0.0628 Val Loss: 0.6400
# [efficientnet] Epoch 7/12 Train Loss: 0.0636 Val Loss: 0.7496
# [efficientnet] Epoch 8/12 Train Loss: 0.0398 Val Loss: 0.5136
# [efficientnet] Epoch 9/12 Train Loss: 0.0420 Val Loss: 0.6309
# [efficientnet] Epoch 10/12 Train Loss: 0.0379 Val Loss: 0.8085
# [efficientnet] Epoch 11/12 Train Loss: 0.0481 Val Loss: 0.5674
# [efficientnet] Epoch 12/12 Train Loss: 0.0457 Val Loss: 0.6738
# DR: best thr=0.75, val F1=0.8313
# Glaucoma: best thr=0.10, val F1=0.7767
# AMD: best thr=0.36, val F1=0.7123
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.001_bs32
# Average F1 over 3 diseases (offsite): 0.6728
#
# OFFSITE Average F1 for this config: 0.6728
# ============================================================
# Experiment 3: lr=0.0009, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3366 Val Loss: 0.4616
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1502 Val Loss: 0.5420
# [efficientnet] Epoch 3/12 Train Loss: 0.0677 Val Loss: 0.6593
# [efficientnet] Epoch 4/12 Train Loss: 0.0567 Val Loss: 0.7775
# [efficientnet] Epoch 5/12 Train Loss: 0.0372 Val Loss: 0.5298
# [efficientnet] Epoch 6/12 Train Loss: 0.0342 Val Loss: 0.6584
# [efficientnet] Epoch 7/12 Train Loss: 0.0281 Val Loss: 0.6128
# [efficientnet] Epoch 8/12 Train Loss: 0.0227 Val Loss: 0.7108
# [efficientnet] Epoch 9/12 Train Loss: 0.0150 Val Loss: 0.5498
# [efficientnet] Epoch 10/12 Train Loss: 0.0177 Val Loss: 0.6462
# [efficientnet] Epoch 11/12 Train Loss: 0.0186 Val Loss: 0.6216
# [efficientnet] Epoch 12/12 Train Loss: 0.0228 Val Loss: 0.6602
# DR: best thr=0.46, val F1=0.8348
# Glaucoma: best thr=0.11, val F1=0.8545
# AMD: best thr=0.25, val F1=0.6588
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0009_bs64
# Average F1 over 3 diseases (offsite): 0.6315
#
# OFFSITE Average F1 for this config: 0.6315
# ============================================================
# Experiment 4: lr=0.0009, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.4014 Val Loss: 0.4089
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1682 Val Loss: 0.5731
# [efficientnet] Epoch 3/12 Train Loss: 0.1033 Val Loss: 0.5317
# [efficientnet] Epoch 4/12 Train Loss: 0.0677 Val Loss: 0.4961
# [efficientnet] Epoch 5/12 Train Loss: 0.0472 Val Loss: 0.8575
# [efficientnet] Epoch 6/12 Train Loss: 0.0830 Val Loss: 0.5643
# [efficientnet] Epoch 7/12 Train Loss: 0.0682 Val Loss: 0.6405
# [efficientnet] Epoch 8/12 Train Loss: 0.0515 Val Loss: 0.7266
# [efficientnet] Epoch 9/12 Train Loss: 0.0390 Val Loss: 0.5242
# [efficientnet] Epoch 10/12 Train Loss: 0.0256 Val Loss: 0.6846
# [efficientnet] Epoch 11/12 Train Loss: 0.0341 Val Loss: 1.0603
# [efficientnet] Epoch 12/12 Train Loss: 0.0337 Val Loss: 0.6352
# DR: best thr=0.26, val F1=0.8000
# Glaucoma: best thr=0.76, val F1=0.8319
# AMD: best thr=0.34, val F1=0.6593
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0009_bs32
# Average F1 over 3 diseases (offsite): 0.7463
#
# OFFSITE Average F1 for this config: 0.7463
# ============================================================
# Experiment 5: lr=0.0008, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3391 Val Loss: 0.6069
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1649 Val Loss: 0.4623
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.0694 Val Loss: 0.5963
# [efficientnet] Epoch 4/12 Train Loss: 0.0423 Val Loss: 0.5420
# [efficientnet] Epoch 5/12 Train Loss: 0.0274 Val Loss: 0.7212
# [efficientnet] Epoch 6/12 Train Loss: 0.0192 Val Loss: 0.6214
# [efficientnet] Epoch 7/12 Train Loss: 0.0277 Val Loss: 0.5929
# [efficientnet] Epoch 8/12 Train Loss: 0.0382 Val Loss: 0.7886
# [efficientnet] Epoch 9/12 Train Loss: 0.0447 Val Loss: 0.5758
# [efficientnet] Epoch 10/12 Train Loss: 0.0283 Val Loss: 0.6218
# [efficientnet] Epoch 11/12 Train Loss: 0.0193 Val Loss: 0.6273
# [efficientnet] Epoch 12/12 Train Loss: 0.0201 Val Loss: 0.6950
# DR: best thr=0.68, val F1=0.8522
# Glaucoma: best thr=0.10, val F1=0.8000
# AMD: best thr=0.23, val F1=0.7105
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0008_bs64
# Average F1 over 3 diseases (offsite): 0.7252
#
# OFFSITE Average F1 for this config: 0.7252
# ============================================================
# Experiment 6: lr=0.0008, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3876 Val Loss: 0.4973
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1892 Val Loss: 0.4406
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.0947 Val Loss: 0.5142
# [efficientnet] Epoch 4/12 Train Loss: 0.0511 Val Loss: 0.5613
# [efficientnet] Epoch 5/12 Train Loss: 0.0376 Val Loss: 0.5099
# [efficientnet] Epoch 6/12 Train Loss: 0.0356 Val Loss: 0.5917
# [efficientnet] Epoch 7/12 Train Loss: 0.0375 Val Loss: 0.7393
# [efficientnet] Epoch 8/12 Train Loss: 0.0608 Val Loss: 0.5825
# [efficientnet] Epoch 9/12 Train Loss: 0.0661 Val Loss: 0.7677
# [efficientnet] Epoch 10/12 Train Loss: 0.0681 Val Loss: 0.6119
# [efficientnet] Epoch 11/12 Train Loss: 0.0832 Val Loss: 0.6970
# [efficientnet] Epoch 12/12 Train Loss: 0.0376 Val Loss: 0.5953
# DR: best thr=0.14, val F1=0.8361
# Glaucoma: best thr=0.55, val F1=0.7810
# AMD: best thr=0.86, val F1=0.6944
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0008_bs32
# Average F1 over 3 diseases (offsite): 0.7309
#
# OFFSITE Average F1 for this config: 0.7309
# ============================================================
# Experiment 7: lr=0.0007, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3173 Val Loss: 0.3667
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1236 Val Loss: 0.4079
# [efficientnet] Epoch 3/12 Train Loss: 0.0650 Val Loss: 0.4426
# [efficientnet] Epoch 4/12 Train Loss: 0.0391 Val Loss: 0.5236
# [efficientnet] Epoch 5/12 Train Loss: 0.0354 Val Loss: 0.6715
# [efficientnet] Epoch 6/12 Train Loss: 0.0391 Val Loss: 0.5519
# [efficientnet] Epoch 7/12 Train Loss: 0.0270 Val Loss: 0.5100
# [efficientnet] Epoch 8/12 Train Loss: 0.0392 Val Loss: 0.4452
# [efficientnet] Epoch 9/12 Train Loss: 0.0187 Val Loss: 0.6111
# [efficientnet] Epoch 10/12 Train Loss: 0.0140 Val Loss: 0.6563
# [efficientnet] Epoch 11/12 Train Loss: 0.0114 Val Loss: 0.5607
# [efficientnet] Epoch 12/12 Train Loss: 0.0090 Val Loss: 0.5786
# DR: best thr=0.77, val F1=0.8370
# Glaucoma: best thr=0.10, val F1=0.8305
# AMD: best thr=0.50, val F1=0.7297
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0007_bs64
# Average F1 over 3 diseases (offsite): 0.7264
#
# OFFSITE Average F1 for this config: 0.7264
# ============================================================
# Experiment 8: lr=0.0007, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3469 Val Loss: 0.3954
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1638 Val Loss: 0.5845
# [efficientnet] Epoch 3/12 Train Loss: 0.0986 Val Loss: 0.4993
# [efficientnet] Epoch 4/12 Train Loss: 0.0703 Val Loss: 0.5649
# [efficientnet] Epoch 5/12 Train Loss: 0.0375 Val Loss: 0.5920
# [efficientnet] Epoch 6/12 Train Loss: 0.0249 Val Loss: 0.7146
# [efficientnet] Epoch 7/12 Train Loss: 0.0379 Val Loss: 0.5775
# [efficientnet] Epoch 8/12 Train Loss: 0.0580 Val Loss: 0.5058
# [efficientnet] Epoch 9/12 Train Loss: 0.0643 Val Loss: 1.0932
# [efficientnet] Epoch 10/12 Train Loss: 0.0651 Val Loss: 0.5669
# [efficientnet] Epoch 11/12 Train Loss: 0.0302 Val Loss: 0.6522
# [efficientnet] Epoch 12/12 Train Loss: 0.0288 Val Loss: 0.5549
# DR: best thr=0.84, val F1=0.8378
# Glaucoma: best thr=0.41, val F1=0.8148
# AMD: best thr=0.10, val F1=0.7368
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0007_bs32
# Average F1 over 3 diseases (offsite): 0.6271
#
# OFFSITE Average F1 for this config: 0.6271
# ============================================================
# Experiment 9: lr=0.0006, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.2991 Val Loss: 0.5123
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1114 Val Loss: 0.5404
# [efficientnet] Epoch 3/12 Train Loss: 0.0582 Val Loss: 0.5632
# [efficientnet] Epoch 4/12 Train Loss: 0.0421 Val Loss: 0.5462
# [efficientnet] Epoch 5/12 Train Loss: 0.0315 Val Loss: 0.5375
# [efficientnet] Epoch 6/12 Train Loss: 0.0331 Val Loss: 0.6040
# [efficientnet] Epoch 7/12 Train Loss: 0.0373 Val Loss: 0.5598
# [efficientnet] Epoch 8/12 Train Loss: 0.0217 Val Loss: 0.6117
# [efficientnet] Epoch 9/12 Train Loss: 0.0266 Val Loss: 0.5916
# [efficientnet] Epoch 10/12 Train Loss: 0.0335 Val Loss: 0.7623
# [efficientnet] Epoch 11/12 Train Loss: 0.0207 Val Loss: 0.5554
# [efficientnet] Epoch 12/12 Train Loss: 0.0158 Val Loss: 0.5556
# DR: best thr=0.40, val F1=0.8362
# Glaucoma: best thr=0.14, val F1=0.8596
# AMD: best thr=0.79, val F1=0.7013
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0006_bs64
# Average F1 over 3 diseases (offsite): 0.7931
#
# OFFSITE Average F1 for this config: 0.7931
# ============================================================
# Experiment 10: lr=0.0006, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3242 Val Loss: 0.4615
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1386 Val Loss: 0.5111
# [efficientnet] Epoch 3/12 Train Loss: 0.0869 Val Loss: 0.5572
# [efficientnet] Epoch 4/12 Train Loss: 0.0547 Val Loss: 0.5626
# [efficientnet] Epoch 5/12 Train Loss: 0.0433 Val Loss: 0.6744
# [efficientnet] Epoch 6/12 Train Loss: 0.0519 Val Loss: 0.6832
# [efficientnet] Epoch 7/12 Train Loss: 0.0339 Val Loss: 0.6775
# [efficientnet] Epoch 8/12 Train Loss: 0.0382 Val Loss: 0.6547
# [efficientnet] Epoch 9/12 Train Loss: 0.0525 Val Loss: 0.6068
# [efficientnet] Epoch 10/12 Train Loss: 0.0675 Val Loss: 0.5667
# [efficientnet] Epoch 11/12 Train Loss: 0.0384 Val Loss: 0.6857
# [efficientnet] Epoch 12/12 Train Loss: 0.0210 Val Loss: 0.6710
# DR: best thr=0.73, val F1=0.8333
# Glaucoma: best thr=0.34, val F1=0.8364
# AMD: best thr=0.32, val F1=0.6944
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0006_bs32
# Average F1 over 3 diseases (offsite): 0.6856
#
# OFFSITE Average F1 for this config: 0.6856
# ============================================================
# Experiment 11: lr=0.0005, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.2870 Val Loss: 0.4292
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1288 Val Loss: 0.4518
# [efficientnet] Epoch 3/12 Train Loss: 0.0685 Val Loss: 0.5346
# [efficientnet] Epoch 4/12 Train Loss: 0.0358 Val Loss: 0.5307
# [efficientnet] Epoch 5/12 Train Loss: 0.0215 Val Loss: 0.6563
# [efficientnet] Epoch 6/12 Train Loss: 0.0208 Val Loss: 0.5493
# [efficientnet] Epoch 7/12 Train Loss: 0.0235 Val Loss: 0.4843
# [efficientnet] Epoch 8/12 Train Loss: 0.0157 Val Loss: 0.5435
# [efficientnet] Epoch 9/12 Train Loss: 0.0196 Val Loss: 0.6099
# [efficientnet] Epoch 10/12 Train Loss: 0.0136 Val Loss: 0.6155
# [efficientnet] Epoch 11/12 Train Loss: 0.0160 Val Loss: 0.6411
# [efficientnet] Epoch 12/12 Train Loss: 0.0187 Val Loss: 0.6502
# DR: best thr=0.26, val F1=0.8448
# Glaucoma: best thr=0.16, val F1=0.8065
# AMD: best thr=0.12, val F1=0.7179
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0005_bs64
# Average F1 over 3 diseases (offsite): 0.7560
#
# OFFSITE Average F1 for this config: 0.7560
# ============================================================
# Experiment 12: lr=0.0005, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3404 Val Loss: 0.3871
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1275 Val Loss: 0.5886
# [efficientnet] Epoch 3/12 Train Loss: 0.0674 Val Loss: 0.6167
# [efficientnet] Epoch 4/12 Train Loss: 0.0454 Val Loss: 0.5219
# [efficientnet] Epoch 5/12 Train Loss: 0.0405 Val Loss: 0.5826
# [efficientnet] Epoch 6/12 Train Loss: 0.0355 Val Loss: 0.6829
# [efficientnet] Epoch 7/12 Train Loss: 0.0307 Val Loss: 0.5708
# [efficientnet] Epoch 8/12 Train Loss: 0.0336 Val Loss: 0.6645
# [efficientnet] Epoch 9/12 Train Loss: 0.0387 Val Loss: 0.7854
# [efficientnet] Epoch 10/12 Train Loss: 0.0304 Val Loss: 0.6112
# [efficientnet] Epoch 11/12 Train Loss: 0.0296 Val Loss: 0.7663
# [efficientnet] Epoch 12/12 Train Loss: 0.0341 Val Loss: 0.5944
# DR: best thr=0.41, val F1=0.8186
# Glaucoma: best thr=0.60, val F1=0.8113
# AMD: best thr=0.11, val F1=0.6667
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0005_bs32
# Average F1 over 3 diseases (offsite): 0.7042
#
# OFFSITE Average F1 for this config: 0.7042
# ============================================================
# Experiment 13: lr=0.0004, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.2884 Val Loss: 0.3910
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1079 Val Loss: 0.4347
# [efficientnet] Epoch 3/12 Train Loss: 0.0652 Val Loss: 0.5175
# [efficientnet] Epoch 4/12 Train Loss: 0.0353 Val Loss: 0.5496
# [efficientnet] Epoch 5/12 Train Loss: 0.0239 Val Loss: 0.5497
# [efficientnet] Epoch 6/12 Train Loss: 0.0190 Val Loss: 0.6062
# [efficientnet] Epoch 7/12 Train Loss: 0.0165 Val Loss: 0.5577
# [efficientnet] Epoch 8/12 Train Loss: 0.0152 Val Loss: 0.6803
# [efficientnet] Epoch 9/12 Train Loss: 0.0296 Val Loss: 0.7110
# [efficientnet] Epoch 10/12 Train Loss: 0.0190 Val Loss: 0.6354
# [efficientnet] Epoch 11/12 Train Loss: 0.0153 Val Loss: 0.6391
# [efficientnet] Epoch 12/12 Train Loss: 0.0143 Val Loss: 0.6418
# DR: best thr=0.19, val F1=0.8395
# Glaucoma: best thr=0.10, val F1=0.8246
# AMD: best thr=0.16, val F1=0.7229
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0004_bs64
# Average F1 over 3 diseases (offsite): 0.7483
#
# OFFSITE Average F1 for this config: 0.7483
# ============================================================
# Experiment 14: lr=0.0004, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3096 Val Loss: 0.4266
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1414 Val Loss: 0.3682
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.0748 Val Loss: 0.4352
# [efficientnet] Epoch 4/12 Train Loss: 0.0448 Val Loss: 0.4845
# [efficientnet] Epoch 5/12 Train Loss: 0.0343 Val Loss: 0.5520
# [efficientnet] Epoch 6/12 Train Loss: 0.0235 Val Loss: 0.5253
# [efficientnet] Epoch 7/12 Train Loss: 0.0298 Val Loss: 0.5333
# [efficientnet] Epoch 8/12 Train Loss: 0.0230 Val Loss: 0.6220
# [efficientnet] Epoch 9/12 Train Loss: 0.0238 Val Loss: 0.5870
# [efficientnet] Epoch 10/12 Train Loss: 0.0361 Val Loss: 0.6267
# [efficientnet] Epoch 11/12 Train Loss: 0.0230 Val Loss: 0.6037
# [efficientnet] Epoch 12/12 Train Loss: 0.0294 Val Loss: 0.7370
# DR: best thr=0.48, val F1=0.8376
# Glaucoma: best thr=0.10, val F1=0.8000
# AMD: best thr=0.34, val F1=0.7073
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0004_bs32
# Average F1 over 3 diseases (offsite): 0.7679
#
# OFFSITE Average F1 for this config: 0.7679
# ============================================================
# Experiment 15: lr=0.0003, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.2932 Val Loss: 0.4730
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1306 Val Loss: 0.4094
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.0628 Val Loss: 0.4780
# [efficientnet] Epoch 4/12 Train Loss: 0.0410 Val Loss: 0.5013
# [efficientnet] Epoch 5/12 Train Loss: 0.0358 Val Loss: 0.5191
# [efficientnet] Epoch 6/12 Train Loss: 0.0277 Val Loss: 0.6257
# [efficientnet] Epoch 7/12 Train Loss: 0.0264 Val Loss: 0.6217
# [efficientnet] Epoch 8/12 Train Loss: 0.0219 Val Loss: 0.5935
# [efficientnet] Epoch 9/12 Train Loss: 0.0194 Val Loss: 0.6095
# [efficientnet] Epoch 10/12 Train Loss: 0.0135 Val Loss: 0.5710
# [efficientnet] Epoch 11/12 Train Loss: 0.0108 Val Loss: 0.6025
# [efficientnet] Epoch 12/12 Train Loss: 0.0092 Val Loss: 0.6250
# DR: best thr=0.69, val F1=0.8534
# Glaucoma: best thr=0.34, val F1=0.7850
# AMD: best thr=0.23, val F1=0.7179
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0003_bs64
# Average F1 over 3 diseases (offsite): 0.7475
#
# OFFSITE Average F1 for this config: 0.7475
# ============================================================
# Experiment 16: lr=0.0003, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.2907 Val Loss: 0.3966
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1286 Val Loss: 0.4145
# [efficientnet] Epoch 3/12 Train Loss: 0.0715 Val Loss: 0.4800
# [efficientnet] Epoch 4/12 Train Loss: 0.0335 Val Loss: 0.5315
# [efficientnet] Epoch 5/12 Train Loss: 0.0254 Val Loss: 0.5369
# [efficientnet] Epoch 6/12 Train Loss: 0.0246 Val Loss: 0.5867
# [efficientnet] Epoch 7/12 Train Loss: 0.0220 Val Loss: 0.5302
# [efficientnet] Epoch 8/12 Train Loss: 0.0184 Val Loss: 0.5682
# [efficientnet] Epoch 9/12 Train Loss: 0.0251 Val Loss: 0.5117
# [efficientnet] Epoch 10/12 Train Loss: 0.0339 Val Loss: 0.6319
# [efficientnet] Epoch 11/12 Train Loss: 0.0510 Val Loss: 0.5799
# [efficientnet] Epoch 12/12 Train Loss: 0.0430 Val Loss: 0.5751
# DR: best thr=0.57, val F1=0.8523
# Glaucoma: best thr=0.10, val F1=0.7788
# AMD: best thr=0.57, val F1=0.7143
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0003_bs32
# Average F1 over 3 diseases (offsite): 0.6683
#
# OFFSITE Average F1 for this config: 0.6683
# ============================================================
# Experiment 17: lr=0.0002, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3016 Val Loss: 0.3782
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1512 Val Loss: 0.3724
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.0809 Val Loss: 0.4382
# [efficientnet] Epoch 4/12 Train Loss: 0.0541 Val Loss: 0.4763
# [efficientnet] Epoch 5/12 Train Loss: 0.0344 Val Loss: 0.4751
# [efficientnet] Epoch 6/12 Train Loss: 0.0269 Val Loss: 0.5001
# [efficientnet] Epoch 7/12 Train Loss: 0.0211 Val Loss: 0.5098
# [efficientnet] Epoch 8/12 Train Loss: 0.0175 Val Loss: 0.5461
# [efficientnet] Epoch 9/12 Train Loss: 0.0139 Val Loss: 0.5761
# [efficientnet] Epoch 10/12 Train Loss: 0.0154 Val Loss: 0.5249
# [efficientnet] Epoch 11/12 Train Loss: 0.0154 Val Loss: 0.5572
# [efficientnet] Epoch 12/12 Train Loss: 0.0206 Val Loss: 0.6388
# DR: best thr=0.89, val F1=0.8452
# Glaucoma: best thr=0.20, val F1=0.7736
# AMD: best thr=0.10, val F1=0.7297
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0002_bs64
# Average F1 over 3 diseases (offsite): 0.7372
#
# OFFSITE Average F1 for this config: 0.7372
# ============================================================
# Experiment 18: lr=0.0002, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3213 Val Loss: 0.3666
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1329 Val Loss: 0.3795
# [efficientnet] Epoch 3/12 Train Loss: 0.0697 Val Loss: 0.3865
# [efficientnet] Epoch 4/12 Train Loss: 0.0581 Val Loss: 0.4557
# [efficientnet] Epoch 5/12 Train Loss: 0.0424 Val Loss: 0.4366
# [efficientnet] Epoch 6/12 Train Loss: 0.0260 Val Loss: 0.4487
# [efficientnet] Epoch 7/12 Train Loss: 0.0306 Val Loss: 0.5027
# [efficientnet] Epoch 8/12 Train Loss: 0.0248 Val Loss: 0.5432
# [efficientnet] Epoch 9/12 Train Loss: 0.0227 Val Loss: 0.5070
# [efficientnet] Epoch 10/12 Train Loss: 0.0192 Val Loss: 0.5119
# [efficientnet] Epoch 11/12 Train Loss: 0.0141 Val Loss: 0.5702
# [efficientnet] Epoch 12/12 Train Loss: 0.0148 Val Loss: 0.5247
# DR: best thr=0.43, val F1=0.8711
# Glaucoma: best thr=0.70, val F1=0.8182
# AMD: best thr=0.40, val F1=0.7342
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0002_bs32
# Average F1 over 3 diseases (offsite): 0.7656
#
# OFFSITE Average F1 for this config: 0.7656
# ============================================================
# Experiment 19: lr=0.0001, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3101 Val Loss: 0.3790
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1910 Val Loss: 0.3723
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.1368 Val Loss: 0.3840
# [efficientnet] Epoch 4/12 Train Loss: 0.1017 Val Loss: 0.3792
# [efficientnet] Epoch 5/12 Train Loss: 0.0692 Val Loss: 0.4116
# [efficientnet] Epoch 6/12 Train Loss: 0.0543 Val Loss: 0.4260
# [efficientnet] Epoch 7/12 Train Loss: 0.0404 Val Loss: 0.4494
# [efficientnet] Epoch 8/12 Train Loss: 0.0361 Val Loss: 0.4524
# [efficientnet] Epoch 9/12 Train Loss: 0.0267 Val Loss: 0.4489
# [efficientnet] Epoch 10/12 Train Loss: 0.0290 Val Loss: 0.4643
# [efficientnet] Epoch 11/12 Train Loss: 0.0265 Val Loss: 0.4951
# [efficientnet] Epoch 12/12 Train Loss: 0.0236 Val Loss: 0.5258
# DR: best thr=0.79, val F1=0.8485
# Glaucoma: best thr=0.15, val F1=0.7748
# AMD: best thr=0.20, val F1=0.7229
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0001_bs64
# Average F1 over 3 diseases (offsite): 0.7540
#
# OFFSITE Average F1 for this config: 0.7540
# ============================================================
# Experiment 20: lr=0.0001, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3111 Val Loss: 0.3562
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1761 Val Loss: 0.3477
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.1152 Val Loss: 0.3796
# [efficientnet] Epoch 4/12 Train Loss: 0.0882 Val Loss: 0.3899
# [efficientnet] Epoch 5/12 Train Loss: 0.0657 Val Loss: 0.3996
# [efficientnet] Epoch 6/12 Train Loss: 0.0521 Val Loss: 0.4293
# [efficientnet] Epoch 7/12 Train Loss: 0.0376 Val Loss: 0.4226
# [efficientnet] Epoch 8/12 Train Loss: 0.0395 Val Loss: 0.4704
# [efficientnet] Epoch 9/12 Train Loss: 0.0367 Val Loss: 0.4454
# [efficientnet] Epoch 10/12 Train Loss: 0.0280 Val Loss: 0.4606
# [efficientnet] Epoch 11/12 Train Loss: 0.0233 Val Loss: 0.5068
# [efficientnet] Epoch 12/12 Train Loss: 0.0173 Val Loss: 0.5310
# DR: best thr=0.80, val F1=0.8596
# Glaucoma: best thr=0.44, val F1=0.7767
# AMD: best thr=0.42, val F1=0.7297
#
# OFFSITE test results for efficientnet - full_ft_cb_lr0.0001_bs32
# Average F1 over 3 diseases (offsite): 0.7294
#
# OFFSITE Average F1 for this config: 0.7294
# ============================================================
# Experiment 21: lr=9e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3294 Val Loss: 0.3733
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1976 Val Loss: 0.3876
# [efficientnet] Epoch 3/12 Train Loss: 0.1365 Val Loss: 0.3777
# [efficientnet] Epoch 4/12 Train Loss: 0.1041 Val Loss: 0.3748
# [efficientnet] Epoch 5/12 Train Loss: 0.0841 Val Loss: 0.3889
# [efficientnet] Epoch 6/12 Train Loss: 0.0556 Val Loss: 0.4071
# [efficientnet] Epoch 7/12 Train Loss: 0.0512 Val Loss: 0.4481
# [efficientnet] Epoch 8/12 Train Loss: 0.0363 Val Loss: 0.4809
# [efficientnet] Epoch 9/12 Train Loss: 0.0380 Val Loss: 0.4781
# [efficientnet] Epoch 10/12 Train Loss: 0.0252 Val Loss: 0.4989
# [efficientnet] Epoch 11/12 Train Loss: 0.0299 Val Loss: 0.5068
# [efficientnet] Epoch 12/12 Train Loss: 0.0288 Val Loss: 0.5155
# DR: best thr=0.68, val F1=0.8475
# Glaucoma: best thr=0.15, val F1=0.7736
# AMD: best thr=0.44, val F1=0.7467
#
# OFFSITE test results for efficientnet - full_ft_cb_lr9e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7153
#
# OFFSITE Average F1 for this config: 0.7153
# ============================================================
# Experiment 22: lr=9e-05, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3263 Val Loss: 0.3730
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1886 Val Loss: 0.3523
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.1326 Val Loss: 0.3639
# [efficientnet] Epoch 4/12 Train Loss: 0.1009 Val Loss: 0.3808
# [efficientnet] Epoch 5/12 Train Loss: 0.0663 Val Loss: 0.4260
# [efficientnet] Epoch 6/12 Train Loss: 0.0517 Val Loss: 0.4323
# [efficientnet] Epoch 7/12 Train Loss: 0.0484 Val Loss: 0.4383
# [efficientnet] Epoch 8/12 Train Loss: 0.0309 Val Loss: 0.4693
# [efficientnet] Epoch 9/12 Train Loss: 0.0328 Val Loss: 0.4577
# [efficientnet] Epoch 10/12 Train Loss: 0.0239 Val Loss: 0.5021
# [efficientnet] Epoch 11/12 Train Loss: 0.0217 Val Loss: 0.5013
# [efficientnet] Epoch 12/12 Train Loss: 0.0252 Val Loss: 0.5145
# DR: best thr=0.61, val F1=0.8523
# Glaucoma: best thr=0.31, val F1=0.7890
# AMD: best thr=0.28, val F1=0.7368
#
# OFFSITE test results for efficientnet - full_ft_cb_lr9e-05_bs32
# Average F1 over 3 diseases (offsite): 0.7529
#
# OFFSITE Average F1 for this config: 0.7529
# ============================================================
# Experiment 23: lr=8e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3367 Val Loss: 0.3630
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.2095 Val Loss: 0.3588
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.1488 Val Loss: 0.3631
# [efficientnet] Epoch 4/12 Train Loss: 0.1117 Val Loss: 0.3726
# [efficientnet] Epoch 5/12 Train Loss: 0.0909 Val Loss: 0.3893
# [efficientnet] Epoch 6/12 Train Loss: 0.0687 Val Loss: 0.3976
# [efficientnet] Epoch 7/12 Train Loss: 0.0570 Val Loss: 0.4225
# [efficientnet] Epoch 8/12 Train Loss: 0.0503 Val Loss: 0.4498
# [efficientnet] Epoch 9/12 Train Loss: 0.0381 Val Loss: 0.4600
# [efficientnet] Epoch 10/12 Train Loss: 0.0343 Val Loss: 0.4610
# [efficientnet] Epoch 11/12 Train Loss: 0.0320 Val Loss: 0.4745
# [efficientnet] Epoch 12/12 Train Loss: 0.0248 Val Loss: 0.4831
# DR: best thr=0.75, val F1=0.8534
# Glaucoma: best thr=0.20, val F1=0.7736
# AMD: best thr=0.30, val F1=0.7368
#
# OFFSITE test results for efficientnet - full_ft_cb_lr8e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7289
#
# OFFSITE Average F1 for this config: 0.7289
# ============================================================
# Experiment 24: lr=8e-05, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3197 Val Loss: 0.3626
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1939 Val Loss: 0.3493
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.1256 Val Loss: 0.3671
# [efficientnet] Epoch 4/12 Train Loss: 0.1037 Val Loss: 0.3687
# [efficientnet] Epoch 5/12 Train Loss: 0.0848 Val Loss: 0.4009
# [efficientnet] Epoch 6/12 Train Loss: 0.0617 Val Loss: 0.4025
# [efficientnet] Epoch 7/12 Train Loss: 0.0513 Val Loss: 0.4237
# [efficientnet] Epoch 8/12 Train Loss: 0.0370 Val Loss: 0.4309
# [efficientnet] Epoch 9/12 Train Loss: 0.0338 Val Loss: 0.4391
# [efficientnet] Epoch 10/12 Train Loss: 0.0301 Val Loss: 0.4612
# [efficientnet] Epoch 11/12 Train Loss: 0.0243 Val Loss: 0.4822
# [efficientnet] Epoch 12/12 Train Loss: 0.0207 Val Loss: 0.5078
# DR: best thr=0.55, val F1=0.8412
# Glaucoma: best thr=0.26, val F1=0.7850
# AMD: best thr=0.16, val F1=0.7381
#
# OFFSITE test results for efficientnet - full_ft_cb_lr8e-05_bs32
# Average F1 over 3 diseases (offsite): 0.7591
#
# OFFSITE Average F1 for this config: 0.7591
# ============================================================
# Experiment 25: lr=7e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3406 Val Loss: 0.3574
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.2207 Val Loss: 0.3633
# [efficientnet] Epoch 3/12 Train Loss: 0.1648 Val Loss: 0.3725
# [efficientnet] Epoch 4/12 Train Loss: 0.1343 Val Loss: 0.3691
# [efficientnet] Epoch 5/12 Train Loss: 0.1036 Val Loss: 0.3671
# [efficientnet] Epoch 6/12 Train Loss: 0.0883 Val Loss: 0.3781
# [efficientnet] Epoch 7/12 Train Loss: 0.0617 Val Loss: 0.3912
# [efficientnet] Epoch 8/12 Train Loss: 0.0578 Val Loss: 0.4187
# [efficientnet] Epoch 9/12 Train Loss: 0.0480 Val Loss: 0.4308
# [efficientnet] Epoch 10/12 Train Loss: 0.0375 Val Loss: 0.4474
# [efficientnet] Epoch 11/12 Train Loss: 0.0345 Val Loss: 0.4503
# [efficientnet] Epoch 12/12 Train Loss: 0.0338 Val Loss: 0.4560
# DR: best thr=0.61, val F1=0.8475
# Glaucoma: best thr=0.10, val F1=0.8000
# AMD: best thr=0.20, val F1=0.7381
#
# OFFSITE test results for efficientnet - full_ft_cb_lr7e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7227
#
# OFFSITE Average F1 for this config: 0.7227
# ============================================================
# Experiment 26: lr=7e-05, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3287 Val Loss: 0.3602
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.2099 Val Loss: 0.3646
# [efficientnet] Epoch 3/12 Train Loss: 0.1496 Val Loss: 0.3620
# [efficientnet] Epoch 4/12 Train Loss: 0.1127 Val Loss: 0.3713
# [efficientnet] Epoch 5/12 Train Loss: 0.0862 Val Loss: 0.3721
# [efficientnet] Epoch 6/12 Train Loss: 0.0701 Val Loss: 0.4062
# [efficientnet] Epoch 7/12 Train Loss: 0.0520 Val Loss: 0.4238
# [efficientnet] Epoch 8/12 Train Loss: 0.0508 Val Loss: 0.4245
# [efficientnet] Epoch 9/12 Train Loss: 0.0371 Val Loss: 0.4393
# [efficientnet] Epoch 10/12 Train Loss: 0.0308 Val Loss: 0.4534
# [efficientnet] Epoch 11/12 Train Loss: 0.0310 Val Loss: 0.4707
# [efficientnet] Epoch 12/12 Train Loss: 0.0278 Val Loss: 0.4931
# DR: best thr=0.78, val F1=0.8559
# Glaucoma: best thr=0.27, val F1=0.7925
# AMD: best thr=0.43, val F1=0.7273
#
# OFFSITE test results for efficientnet - full_ft_cb_lr7e-05_bs32
# Average F1 over 3 diseases (offsite): 0.7400
#
# OFFSITE Average F1 for this config: 0.7400
# ============================================================
# Experiment 27: lr=6e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3505 Val Loss: 0.3523
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.2370 Val Loss: 0.3594
# [efficientnet] Epoch 3/12 Train Loss: 0.1820 Val Loss: 0.3608
# [efficientnet] Epoch 4/12 Train Loss: 0.1387 Val Loss: 0.3627
# [efficientnet] Epoch 5/12 Train Loss: 0.1158 Val Loss: 0.3698
# [efficientnet] Epoch 6/12 Train Loss: 0.0959 Val Loss: 0.3845
# [efficientnet] Epoch 7/12 Train Loss: 0.0831 Val Loss: 0.3960
# [efficientnet] Epoch 8/12 Train Loss: 0.0680 Val Loss: 0.4125
# [efficientnet] Epoch 9/12 Train Loss: 0.0558 Val Loss: 0.4277
# [efficientnet] Epoch 10/12 Train Loss: 0.0514 Val Loss: 0.4256
# [efficientnet] Epoch 11/12 Train Loss: 0.0446 Val Loss: 0.4380
# [efficientnet] Epoch 12/12 Train Loss: 0.0374 Val Loss: 0.4545
# DR: best thr=0.80, val F1=0.8458
# Glaucoma: best thr=0.26, val F1=0.7850
# AMD: best thr=0.20, val F1=0.7470
#
# OFFSITE test results for efficientnet - full_ft_cb_lr6e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7334
#
# OFFSITE Average F1 for this config: 0.7334
# ============================================================
# Experiment 28: lr=6e-05, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3302 Val Loss: 0.3527
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.2163 Val Loss: 0.3672
# [efficientnet] Epoch 3/12 Train Loss: 0.1631 Val Loss: 0.3618
# [efficientnet] Epoch 4/12 Train Loss: 0.1300 Val Loss: 0.3727
# [efficientnet] Epoch 5/12 Train Loss: 0.1065 Val Loss: 0.3942
# [efficientnet] Epoch 6/12 Train Loss: 0.0854 Val Loss: 0.4026
# [efficientnet] Epoch 7/12 Train Loss: 0.0698 Val Loss: 0.4180
# [efficientnet] Epoch 8/12 Train Loss: 0.0558 Val Loss: 0.4290
# [efficientnet] Epoch 9/12 Train Loss: 0.0457 Val Loss: 0.4492
# [efficientnet] Epoch 10/12 Train Loss: 0.0343 Val Loss: 0.4491
# [efficientnet] Epoch 11/12 Train Loss: 0.0450 Val Loss: 0.4532
# [efficientnet] Epoch 12/12 Train Loss: 0.0348 Val Loss: 0.4656
# DR: best thr=0.80, val F1=0.8634
# Glaucoma: best thr=0.25, val F1=0.7706
# AMD: best thr=0.21, val F1=0.7381
#
# OFFSITE test results for efficientnet - full_ft_cb_lr6e-05_bs32
# Average F1 over 3 diseases (offsite): 0.7073
#
# OFFSITE Average F1 for this config: 0.7073
# ============================================================
# Experiment 29: lr=5e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3506 Val Loss: 0.3519
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.2470 Val Loss: 0.3608
# [efficientnet] Epoch 3/12 Train Loss: 0.1936 Val Loss: 0.3593
# [efficientnet] Epoch 4/12 Train Loss: 0.1568 Val Loss: 0.3625
# [efficientnet] Epoch 5/12 Train Loss: 0.1371 Val Loss: 0.3695
# [efficientnet] Epoch 6/12 Train Loss: 0.1206 Val Loss: 0.3737
# [efficientnet] Epoch 7/12 Train Loss: 0.0969 Val Loss: 0.3791
# [efficientnet] Epoch 8/12 Train Loss: 0.0852 Val Loss: 0.3838
# [efficientnet] Epoch 9/12 Train Loss: 0.0670 Val Loss: 0.3929
# [efficientnet] Epoch 10/12 Train Loss: 0.0559 Val Loss: 0.4046
# [efficientnet] Epoch 11/12 Train Loss: 0.0553 Val Loss: 0.4120
# [efficientnet] Epoch 12/12 Train Loss: 0.0557 Val Loss: 0.4208
# DR: best thr=0.50, val F1=0.8465
# Glaucoma: best thr=0.33, val F1=0.7850
# AMD: best thr=0.34, val F1=0.7273
#
# OFFSITE test results for efficientnet - full_ft_cb_lr5e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7228
#
# OFFSITE Average F1 for this config: 0.7228
# ============================================================
# Experiment 30: lr=5e-05, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3348 Val Loss: 0.3515
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.2187 Val Loss: 0.3513
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.1742 Val Loss: 0.3417
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 4/12 Train Loss: 0.1412 Val Loss: 0.3511
# [efficientnet] Epoch 5/12 Train Loss: 0.1234 Val Loss: 0.3604
# [efficientnet] Epoch 6/12 Train Loss: 0.0967 Val Loss: 0.3784
# [efficientnet] Epoch 7/12 Train Loss: 0.0837 Val Loss: 0.3784
# [efficientnet] Epoch 8/12 Train Loss: 0.0622 Val Loss: 0.4080
# [efficientnet] Epoch 9/12 Train Loss: 0.0562 Val Loss: 0.4100
# [efficientnet] Epoch 10/12 Train Loss: 0.0481 Val Loss: 0.4302
# [efficientnet] Epoch 11/12 Train Loss: 0.0518 Val Loss: 0.4524
# [efficientnet] Epoch 12/12 Train Loss: 0.0442 Val Loss: 0.4425
# DR: best thr=0.69, val F1=0.8485
# Glaucoma: best thr=0.23, val F1=0.7818
# AMD: best thr=0.37, val F1=0.7368
#
# OFFSITE test results for efficientnet - full_ft_cb_lr5e-05_bs32
# Average F1 over 3 diseases (offsite): 0.7406
#
# OFFSITE Average F1 for this config: 0.7406
# ============================================================
# Experiment 31: lr=4e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3578 Val Loss: 0.3524
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.2687 Val Loss: 0.3498
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.2188 Val Loss: 0.3482
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 4/12 Train Loss: 0.1869 Val Loss: 0.3492
# [efficientnet] Epoch 5/12 Train Loss: 0.1470 Val Loss: 0.3551
# [efficientnet] Epoch 6/12 Train Loss: 0.1349 Val Loss: 0.3647
# [efficientnet] Epoch 7/12 Train Loss: 0.1312 Val Loss: 0.3679
# [efficientnet] Epoch 8/12 Train Loss: 0.1117 Val Loss: 0.3715
# [efficientnet] Epoch 9/12 Train Loss: 0.0903 Val Loss: 0.3751
# [efficientnet] Epoch 10/12 Train Loss: 0.0730 Val Loss: 0.3798
# [efficientnet] Epoch 11/12 Train Loss: 0.0729 Val Loss: 0.3896
# [efficientnet] Epoch 12/12 Train Loss: 0.0638 Val Loss: 0.4073
# DR: best thr=0.38, val F1=0.8455
# Glaucoma: best thr=0.24, val F1=0.7850
# AMD: best thr=0.37, val F1=0.7500
#
# OFFSITE test results for efficientnet - full_ft_cb_lr4e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7624
#
# OFFSITE Average F1 for this config: 0.7624
# ============================================================
# Experiment 32: lr=4e-05, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3464 Val Loss: 0.3527
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.2529 Val Loss: 0.3491
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.1905 Val Loss: 0.3452
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 4/12 Train Loss: 0.1707 Val Loss: 0.3565
# [efficientnet] Epoch 5/12 Train Loss: 0.1288 Val Loss: 0.3724
# [efficientnet] Epoch 6/12 Train Loss: 0.1224 Val Loss: 0.3695
# [efficientnet] Epoch 7/12 Train Loss: 0.0971 Val Loss: 0.3685
# [efficientnet] Epoch 8/12 Train Loss: 0.0817 Val Loss: 0.3826
# [efficientnet] Epoch 9/12 Train Loss: 0.0773 Val Loss: 0.3835
# [efficientnet] Epoch 10/12 Train Loss: 0.0663 Val Loss: 0.4015
# [efficientnet] Epoch 11/12 Train Loss: 0.0572 Val Loss: 0.4140
# [efficientnet] Epoch 12/12 Train Loss: 0.0515 Val Loss: 0.4131
# DR: best thr=0.53, val F1=0.8500
# Glaucoma: best thr=0.30, val F1=0.7850
# AMD: best thr=0.13, val F1=0.7368
#
# OFFSITE test results for efficientnet - full_ft_cb_lr4e-05_bs32
# Average F1 over 3 diseases (offsite): 0.7392
#
# OFFSITE Average F1 for this config: 0.7392
# ============================================================
# Experiment 33: lr=3e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3631 Val Loss: 0.3644
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.2863 Val Loss: 0.3561
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.2338 Val Loss: 0.3551
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 4/12 Train Loss: 0.2123 Val Loss: 0.3528
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 5/12 Train Loss: 0.1757 Val Loss: 0.3551
# [efficientnet] Epoch 6/12 Train Loss: 0.1705 Val Loss: 0.3583
# [efficientnet] Epoch 7/12 Train Loss: 0.1495 Val Loss: 0.3558
# [efficientnet] Epoch 8/12 Train Loss: 0.1274 Val Loss: 0.3582
# [efficientnet] Epoch 9/12 Train Loss: 0.1222 Val Loss: 0.3654
# [efficientnet] Epoch 10/12 Train Loss: 0.1074 Val Loss: 0.3709
# [efficientnet] Epoch 11/12 Train Loss: 0.0998 Val Loss: 0.3835
# [efficientnet] Epoch 12/12 Train Loss: 0.0890 Val Loss: 0.3798
# DR: best thr=0.70, val F1=0.8534
# Glaucoma: best thr=0.10, val F1=0.8062
# AMD: best thr=0.30, val F1=0.7342
#
# OFFSITE test results for efficientnet - full_ft_cb_lr3e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7574
#
# OFFSITE Average F1 for this config: 0.7574
# ============================================================
# Experiment 34: lr=3e-05, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3503 Val Loss: 0.3589
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.2654 Val Loss: 0.3486
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.2198 Val Loss: 0.3486
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 4/12 Train Loss: 0.1782 Val Loss: 0.3507
# [efficientnet] Epoch 5/12 Train Loss: 0.1599 Val Loss: 0.3610
# [efficientnet] Epoch 6/12 Train Loss: 0.1377 Val Loss: 0.3618
# [efficientnet] Epoch 7/12 Train Loss: 0.1324 Val Loss: 0.3728
# [efficientnet] Epoch 8/12 Train Loss: 0.1089 Val Loss: 0.3652
# [efficientnet] Epoch 9/12 Train Loss: 0.0948 Val Loss: 0.3705
# [efficientnet] Epoch 10/12 Train Loss: 0.0898 Val Loss: 0.3840
# [efficientnet] Epoch 11/12 Train Loss: 0.0800 Val Loss: 0.3770
# [efficientnet] Epoch 12/12 Train Loss: 0.0698 Val Loss: 0.3809
# DR: best thr=0.60, val F1=0.8511
# Glaucoma: best thr=0.11, val F1=0.7869
# AMD: best thr=0.38, val F1=0.7436
#
# OFFSITE test results for efficientnet - full_ft_cb_lr3e-05_bs32
# Average F1 over 3 diseases (offsite): 0.7551
#
# OFFSITE Average F1 for this config: 0.7551
# ============================================================
# Experiment 35: lr=2e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3712 Val Loss: 0.3862
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.3132 Val Loss: 0.3620
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.2748 Val Loss: 0.3500
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 4/12 Train Loss: 0.2493 Val Loss: 0.3482
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 5/12 Train Loss: 0.2253 Val Loss: 0.3477
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 6/12 Train Loss: 0.2028 Val Loss: 0.3490
# [efficientnet] Epoch 7/12 Train Loss: 0.1825 Val Loss: 0.3488
# [efficientnet] Epoch 8/12 Train Loss: 0.1780 Val Loss: 0.3508
# [efficientnet] Epoch 9/12 Train Loss: 0.1543 Val Loss: 0.3518
# [efficientnet] Epoch 10/12 Train Loss: 0.1536 Val Loss: 0.3537
# [efficientnet] Epoch 11/12 Train Loss: 0.1406 Val Loss: 0.3568
# [efficientnet] Epoch 12/12 Train Loss: 0.1283 Val Loss: 0.3589
# DR: best thr=0.32, val F1=0.8434
# Glaucoma: best thr=0.16, val F1=0.8095
# AMD: best thr=0.57, val F1=0.7123
#
# OFFSITE test results for efficientnet - full_ft_cb_lr2e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7428
#
# OFFSITE Average F1 for this config: 0.7428
# ============================================================
# Experiment 36: lr=2e-05, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3670 Val Loss: 0.3743
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.3079 Val Loss: 0.3615
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.2630 Val Loss: 0.3568
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 4/12 Train Loss: 0.2325 Val Loss: 0.3472
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 5/12 Train Loss: 0.2027 Val Loss: 0.3516
# [efficientnet] Epoch 6/12 Train Loss: 0.1873 Val Loss: 0.3572
# [efficientnet] Epoch 7/12 Train Loss: 0.1764 Val Loss: 0.3520
# [efficientnet] Epoch 8/12 Train Loss: 0.1514 Val Loss: 0.3543
# [efficientnet] Epoch 9/12 Train Loss: 0.1422 Val Loss: 0.3589
# [efficientnet] Epoch 10/12 Train Loss: 0.1226 Val Loss: 0.3616
# [efficientnet] Epoch 11/12 Train Loss: 0.1237 Val Loss: 0.3726
# [efficientnet] Epoch 12/12 Train Loss: 0.1100 Val Loss: 0.3692
# DR: best thr=0.64, val F1=0.8487
# Glaucoma: best thr=0.10, val F1=0.7874
# AMD: best thr=0.36, val F1=0.7179
#
# OFFSITE test results for efficientnet - full_ft_cb_lr2e-05_bs32
# Average F1 over 3 diseases (offsite): 0.7565
#
# OFFSITE Average F1 for this config: 0.7565
# ============================================================
# Experiment 37: lr=1e-05, batch_size=64
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3826 Val Loss: 0.3995
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.3532 Val Loss: 0.3888
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.3200 Val Loss: 0.3789
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 4/12 Train Loss: 0.3103 Val Loss: 0.3702
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 5/12 Train Loss: 0.2926 Val Loss: 0.3638
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 6/12 Train Loss: 0.2620 Val Loss: 0.3604
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 7/12 Train Loss: 0.2495 Val Loss: 0.3553
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 8/12 Train Loss: 0.2403 Val Loss: 0.3538
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 9/12 Train Loss: 0.2243 Val Loss: 0.3535
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 10/12 Train Loss: 0.2182 Val Loss: 0.3529
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 11/12 Train Loss: 0.2082 Val Loss: 0.3501
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 12/12 Train Loss: 0.2016 Val Loss: 0.3502
# DR: best thr=0.52, val F1=0.8443
# Glaucoma: best thr=0.24, val F1=0.8065
# AMD: best thr=0.44, val F1=0.6914
#
# OFFSITE test results for efficientnet - full_ft_cb_lr1e-05_bs64
# Average F1 over 3 diseases (offsite): 0.7404
#
# OFFSITE Average F1 for this config: 0.7404
# ============================================================
# Experiment 38: lr=1e-05, batch_size=32
# ============================================================
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3792 Val Loss: 0.3968
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.3446 Val Loss: 0.3847
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.3039 Val Loss: 0.3644
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 4/12 Train Loss: 0.2845 Val Loss: 0.3604
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 5/12 Train Loss: 0.2612 Val Loss: 0.3602
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 6/12 Train Loss: 0.2476 Val Loss: 0.3514
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 7/12 Train Loss: 0.2365 Val Loss: 0.3524
# [efficientnet] Epoch 8/12 Train Loss: 0.2157 Val Loss: 0.3469
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 9/12 Train Loss: 0.2046 Val Loss: 0.3447
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 10/12 Train Loss: 0.1976 Val Loss: 0.3473
# [efficientnet] Epoch 11/12 Train Loss: 0.1805 Val Loss: 0.3462
# [efficientnet] Epoch 12/12 Train Loss: 0.1798 Val Loss: 0.3456
# DR: best thr=0.48, val F1=0.8443
# Glaucoma: best thr=0.19, val F1=0.7969
# AMD: best thr=0.47, val F1=0.7105
#
# OFFSITE test results for efficientnet - full_ft_cb_lr1e-05_bs32
# Average F1 over 3 diseases (offsite): 0.7620
#
# OFFSITE Average F1 for this config: 0.7620
#
# ############################################################
# TOP 3 CONFIGURATIONS (by OFFSITE average F1)
# ############################################################
# Rank 1: avg_F1=0.7931, lr=0.0006, batch_size=64, ckpt=checkpoints\csu_task2_2_efficientnet.pt
# Rank 2: avg_F1=0.7679, lr=0.0004, batch_size=32, ckpt=checkpoints\csu_task2_2_efficientnet.pt
# Rank 3: avg_F1=0.7656, lr=0.0002, batch_size=32, ckpt=checkpoints\csu_task2_2_efficientnet.pt

# %%
# Task 2.2  efficientnet, cb

backbone = "efficientnet" 

if backbone == "resnet18":
    pretrained_path = pretrained_resnet18
elif backbone == "efficientnet":
    pretrained_path = pretrained_efficient
else:
    raise ValueError("unknown backbone")
    
checkpoint = "./checkpoints/task1/csu_task1_2_efficientnet.pt"
#offsite
ckpt_task21, y_true_offsite, y_pred_offsite, val_probs, val_labels = train_one_backbone(
    backbone=backbone,
    train_csv=train_csv,
    val_csv=val_csv,
    test_csv=offsite_test_csv,
    train_image_dir=train_img_dir,
    val_image_dir=val_img_dir,
    test_image_dir=offsite_img_dir,
    epochs=12,
    batch_size=32,
    lr=0.0004,
    img_size=img_size,
    save_dir=save_dir,
    pretrained_backbone=checkpoint,
    task="full_ft",
    loss="cb", 
)


best_thrs = find_best_thresholds(val_probs, val_labels)

#onsite
generate_kaggle_submission(
    backbone=backbone,
    ckpt_path=ckpt_task21,
    onsite_csv=onsite_csv,          
    onsite_image_dir=onsite_img_dir,
    img_size=img_size,
    batch_size=batch_size,
    out_csv=f"submission_{backbone}_task2_2.csv",
    threshold = 0.5,
    best = False,
)

df_offsite = evaluating_metrics(
    y_true=y_true_offsite,
    y_pred=y_pred_offsite,
    backbone=backbone,
    task_name="full_ft",
    split_name="offsite",
)


torch.cuda.empty_cache()
df_offsite
# Out:
# cuda
# ===========================================
# Task 2 |  Backbone: efficientnet | loss: cb
# ===========================================
# Loaded pretrained weights from ./checkpoints/task1/csu_task1_2_efficientnet.pt
# [efficientnet] Epoch 1/12 Train Loss: 0.3241 Val Loss: 0.4611
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 2/12 Train Loss: 0.1322 Val Loss: 0.4055
# Saved best model for efficientnet (full_ft) at checkpoints\csu_task2_2_efficientnet.pt
# [efficientnet] Epoch 3/12 Train Loss: 0.0653 Val Loss: 0.4971
# [efficientnet] Epoch 4/12 Train Loss: 0.0438 Val Loss: 0.5056
# [efficientnet] Epoch 5/12 Train Loss: 0.0414 Val Loss: 0.6185
# [efficientnet] Epoch 6/12 Train Loss: 0.0341 Val Loss: 0.6243
# [efficientnet] Epoch 7/12 Train Loss: 0.0397 Val Loss: 0.6943
# [efficientnet] Epoch 8/12 Train Loss: 0.0244 Val Loss: 0.6104
# [efficientnet] Epoch 9/12 Train Loss: 0.0203 Val Loss: 0.6425
# [efficientnet] Epoch 10/12 Train Loss: 0.0295 Val Loss: 0.5694
# [efficientnet] Epoch 11/12 Train Loss: 0.0237 Val Loss: 0.6006
# [efficientnet] Epoch 12/12 Train Loss: 0.0301 Val Loss: 0.7280
# DR: best thr=0.60, val F1=0.8205
# Glaucoma: best thr=0.10, val F1=0.7573
# AMD: best thr=0.74, val F1=0.6824
# Kaggle submission saved to: submission\submission_efficientnet_task2_2.csv
#
# OFFSITE test results for efficientnet - full_ft
# Average F1 over 3 diseases (offsite): 0.7728
#        Backbone     Task    Split     Disease  Accuracy  Precision    Recall  \
# 0  efficientnet  full_ft  offsite          DR     0.835   0.879433  0.885714
# 1  efficientnet  full_ft  offsite    Glaucoma     0.895   0.833333  0.714286
# 2  efficientnet  full_ft  offsite         AMD     0.930   0.700000  0.636364
# 3  efficientnet  full_ft  offsite  Average F1       NaN        NaN       NaN
#
#    F1-score     Kappa
# 0  0.882562  0.605263
# 1  0.769231  0.701789
# 2  0.666667  0.627660
# 3  0.772820       NaN
